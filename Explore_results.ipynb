# %% [markdown]
# # Bioinfomatic central script
# insert introduction

# %% [markdown]
# # Specify file location
#
# First, we'll need to specify the location of important files.
#
#     You'll need to input files associated with the microbiome and resistome seperately. This allows for the option of including microbiome results from qiime2 or kraken2.
#
#         For the resistome:
#             > Metadata file for all resistome samples (.csv)
#             > Megares annotation file (.csv)
#             > Count table results from the AMRplusplus pipeline (.csv)
#         For the microbiome
#             > Metadata file for all microbiome samples (.tsv)
#             > etc..

# %% [markdown]
# # For the resistome:

# %%
# Where is the metadata file stored?
amr_metadata_filepath = 'data/resistome_amr++/AMR_metadata.csv'
amr_count_matrix_filepath = 'data/resistome_amr++/strict_SNP_confirmed_AMR_analytic_matrix.csv'
# Name of the megares annotation file used for this project
megares_annotation_filename = 'data/resistome_amr++/megares_annotations_v1.03.csv'

# %% [markdown]
# # For the microbiome:

# %%
# Where is the metadata file for the microbiome samples stored?
microbiome_temp_metadata_file = "data/microbiome-qiime2/Microbiome_metadata.csv"

# Location of results extracted from qiime2
biom_file <- "data/microbiome-qiime2/otu_table_json.biom"
tre_file <- "data/microbiome-qiime2/tree.nwk"
tax_fasta <- "data/microbiome-qiime2/aligned-dna-sequences.fasta"
taxa_file <- "data/microbiome-qiime2/taxonomy.tsv"

# %% [markdown]
# # Running the "Main_script.R"
# This repository consists of a collection of scripts that can be used to process count tables and create exploratory figures.
#
# If you'd like to know exactly how that is being done, explore the "Main_script.R" script in the root directory of this repository. Briefly, it does the following:
# * Points to the location of relevant files containig the microbiome and resistome results
# * Lists the metadata variables to use in our data analysis
# * Runs additional scripts in the "scripts" directory:
#   * To read-in data and create normalized counts
#     * scripts/metagenomeSeq_qiime2.R
#     * scripts/metagenomeSeq_megares.R
#   * To print out aggregated count matrices and exploratory figures:
#     * scripts/print_AMR_figures.R
#     * scripts/print_microbiome_figures.R
#   * To run differential abundance testing using a zero-inflated Gaussian Model (ZIG)
#     * scripts/print_AMR_ZIG_results.R
#     * scripts/print_microbiome_ZIG_results.R

# %%
# You'll notice that no "sparse" features were removed from either the microbiome or the resistome.
# The package, MetagenomeSeq, outputs a warning that the Default quantile value is being used for normalization.
# Lastly, you'll see output from NMDS ordination as the scripts recreates exploratory figures in the "graphs" directory.
source("Main_script.R")
# Out:
# Default value being used.
# [1] "No microbiome features removed"
# Default value being used.
# [1] "No AMR features removed"
# Default value being used.
# [1] "Blinded_Store"
# [1] "Dilution"
# [1] "ID"
# [1] "City"
# [1] "Treatment"
# [1] "Packaging"
# [1] "sample"
# Run 0 stress 0.05294869
# Run 1 stress 0.05294941
# ... Procrustes: rmse 0.0007888202  max resid 0.003710968
# ... Similar to previous best
# Run 2 stress 0.05294864
# ... New best solution
# ... Procrustes: rmse 0.000653703  max resid 0.003065359
# ... Similar to previous best
# Run 3 stress 0.05294768
# ... New best solution
# ... Procrustes: rmse 0.0003843088  max resid 0.001925675
# ... Similar to previous best
# Run 4 stress 0.05294859
# ... Procrustes: rmse 0.000377003  max resid 0.001888223
# ... Similar to previous best
# Run 5 stress 0.05294814
# ... Procrustes: rmse 0.0001675885  max resid 0.0003873323
# ... Similar to previous best
# Run 6 stress 0.05294846
# ... Procrustes: rmse 0.0003597035  max resid 0.001798285
# ... Similar to previous best
# Run 7 stress 0.05294929
# ... Procrustes: rmse 0.0005013635  max resid 0.002507943
# ... Similar to previous best
# Run 8 stress 0.3933287
# Run 9 stress 0.1040312
# Run 10 stress 0.05294807
# ... Procrustes: rmse 0.0002529989  max resid 0.00124459
# ... Similar to previous best
# Run 11 stress 0.05294801
# ... Procrustes: rmse 0.0002234933  max resid 0.0006072182
# ... Similar to previous best
# Run 12 stress 0.05295001
# ... Procrustes: rmse 0.0005668458  max resid 0.002829137
# ... Similar to previous best
# Run 13 stress 0.05294869
# ... Procrustes: rmse 0.0004047906  max resid 0.002027713
# ... Similar to previous best
# Run 14 stress 0.05294787
# ... Procrustes: rmse 0.0001758248  max resid 0.00082455
# ... Similar to previous best
# Run 15 stress 0.05294915
# ... Procrustes: rmse 0.0003999355  max resid 0.001992894
# ... Similar to previous best
# Run 16 stress 0.05294791
# ... Procrustes: rmse 0.0002033691  max resid 0.000816944
# ... Similar to previous best
# Run 17 stress 0.1044947
# Run 18 stress 0.05294846
# ... Procrustes: rmse 0.0002242134  max resid 0.0007921085
# ... Similar to previous best
# Run 19 stress 0.1041015
# Run 20 stress 0.05294923
# ... Procrustes: rmse 0.000495217  max resid 0.002457553
# ... Similar to previous best
# *** Solution reached
# Run 0 stress 0.1083899
# Run 1 stress 0.1462154
# Run 2 stress 0.1091857
# Run 3 stress 0.1429019
# Run 4 stress 0.1498984
# Run 5 stress 0.119862
# Run 6 stress 0.1083901
# ... Procrustes: rmse 0.000218141  max resid 0.0005609948
# ... Similar to previous best
# Run 7 stress 0.1091858
# Run 8 stress 0.1082857
# ... New best solution
# ... Procrustes: rmse 0.01781185  max resid 0.07913172
# Run 9 stress 0.1083327
# ... Procrustes: rmse 0.003495672  max resid 0.01408914
# Run 10 stress 0.1461766
# Run 11 stress 0.1083899
# ... Procrustes: rmse 0.01782894  max resid 0.07927965
# Run 12 stress 0.1083327
# ... Procrustes: rmse 0.003495329  max resid 0.01407522
# Run 13 stress 0.1196991
# Run 14 stress 0.1434843
# Run 15 stress 0.1198824
# Run 16 stress 0.119862
# Run 17 stress 0.1084877
# ... Procrustes: rmse 0.01711179  max resid 0.07938831
# Run 18 stress 0.1464913
# Run 19 stress 0.1904683
# Run 20 stress 0.1091857
# Run 21 stress 0.1082856
# ... New best solution
# ... Procrustes: rmse 8.946375e-05  max resid 0.0002505638
# ... Similar to previous best
# *** Solution reached
# Run 0 stress 0.09575946
# Run 1 stress 0.1290502
# Run 2 stress 0.1072642
# Run 3 stress 0.1277091
# Run 4 stress 0.1549477
# Run 5 stress 0.1075324
# Run 6 stress 0.09305447
# ... New best solution
# ... Procrustes: rmse 0.02469214  max resid 0.1131379
# Run 7 stress 0.09553172
# Run 8 stress 0.1075108
# Run 9 stress 0.1062493
# Run 10 stress 0.09649185
# Run 11 stress 0.09903729
# Run 12 stress 0.09183718
# ... New best solution
# ... Procrustes: rmse 0.007564086  max resid 0.03429276
# Run 13 stress 0.09575971
# Run 14 stress 0.1288744
# Run 15 stress 0.09305463
# Run 16 stress 0.1272607
# Run 17 stress 0.1249512
# Run 18 stress 0.1281138
# Run 19 stress 0.09553173
# Run 20 stress 0.09649371
# Run 21 stress 0.127834
# Run 22 stress 0.09639808
# Run 23 stress 0.150035
# Run 24 stress 0.1108182
# Run 25 stress 0.1107494
# Run 26 stress 0.1274954
# Run 27 stress 0.1052374
# Run 28 stress 0.0948884
# Run 29 stress 0.1293272
# Run 30 stress 0.1266102
# Run 31 stress 0.1255477
# Run 32 stress 0.09183642
# ... New best solution
# ... Procrustes: rmse 0.0003975402  max resid 0.001709496
# ... Similar to previous best
# *** Solution reached
# Run 0 stress 0.1004024
# Run 1 stress 0.1126025
# Run 2 stress 0.1134599
# Run 3 stress 0.103983
# Run 4 stress 0.1004024
# ... Procrustes: rmse 2.330781e-05  max resid 5.770277e-05
# ... Similar to previous best
# Run 5 stress 0.1004024
# ... New best solution
# ... Procrustes: rmse 2.984918e-05  max resid 0.0001139611
# ... Similar to previous best
# Run 6 stress 0.1053412
# Run 7 stress 0.1004024
# ... New best solution
# ... Procrustes: rmse 7.681525e-06  max resid 1.863137e-05
# ... Similar to previous best
# Run 8 stress 0.1048424
# Run 9 stress 0.09917911
# ... New best solution
# ... Procrustes: rmse 0.02343744  max resid 0.0939052
# Run 10 stress 0.1039086
# Run 11 stress 0.3932819
# Run 12 stress 0.09917912
# ... Procrustes: rmse 8.409606e-05  max resid 0.0001612197
# ... Similar to previous best
# Run 13 stress 0.09893561
# ... New best solution
# ... Procrustes: rmse 0.01146659  max resid 0.04936373
# Run 14 stress 0.1004024
# Run 15 stress 0.1039837
# Run 16 stress 0.09917909
# ... Procrustes: rmse 0.01148287  max resid 0.04918651
# Run 17 stress 0.113982
# Run 18 stress 0.1569552
# Run 19 stress 0.1004024
# Run 20 stress 0.1126024
# Run 21 stress 0.0989359
# ... Procrustes: rmse 6.388272e-05  max resid 0.0002147132
# ... Similar to previous best
# *** Solution reached
# Run 0 stress 0.05294869
# Run 1 stress 0.05294842
# ... New best solution
# ... Procrustes: rmse 0.0006094464  max resid 0.002850586
# ... Similar to previous best
# Run 2 stress 0.0529484
# ... New best solution
# ... Procrustes: rmse 0.000124537  max resid 0.000431854
# ... Similar to previous best
# Run 3 stress 0.05295028
# ... Procrustes: rmse 0.0002151243  max resid 0.001018848
# ... Similar to previous best
# Run 4 stress 0.05294778
# ... New best solution
# ... Procrustes: rmse 0.0002455004  max resid 0.001233598
# ... Similar to previous best
# Run 5 stress 0.05294772
# ... New best solution
# ... Procrustes: rmse 0.0001280194  max resid 0.0004204825
# ... Similar to previous best
# Run 6 stress 0.05294886
# ... Procrustes: rmse 0.0003113254  max resid 0.001580322
# ... Similar to previous best
# Run 7 stress 0.05294828
# ... Procrustes: rmse 0.0001657045  max resid 0.0008279926
# ... Similar to previous best
# Run 8 stress 0.05294887
# ... Procrustes: rmse 0.0003040405  max resid 0.001106491
# ... Similar to previous best
# Run 9 stress 0.05294889
# ... Procrustes: rmse 0.0003244928  max resid 0.001651737
# ... Similar to previous best
# Run 10 stress 0.05295
# ... Procrustes: rmse 0.0004881488  max resid 0.0024557
# ... Similar to previous best
# Run 11 stress 0.0529494
# ... Procrustes: rmse 0.0004131093  max resid 0.002061058
# ... Similar to previous best
# Run 12 stress 0.05294942
# ... Procrustes: rmse 0.0002936945  max resid 0.001441198
# ... Similar to previous best
# Run 13 stress 0.1043165
# Run 14 stress 0.1040316
# Run 15 stress 0.05294978
# ... Procrustes: rmse 0.0004687738  max resid 0.002316658
# ... Similar to previous best
# Run 16 stress 0.05294903
# ... Procrustes: rmse 0.0002667554  max resid 0.001330228
# ... Similar to previous best
# Run 17 stress 0.1055807
# Run 18 stress 0.05295075
# ... Procrustes: rmse 0.0005706301  max resid 0.002867038
# ... Similar to previous best
# Run 19 stress 0.0529478
# ... Procrustes: rmse 9.703687e-05  max resid 0.0004542059
# ... Similar to previous best
# Run 20 stress 0.05294942
# ... Procrustes: rmse 0.0004045912  max resid 0.001999697
# ... Similar to previous best
# *** Solution reached
# Run 0 stress 0.1083899
# Run 1 stress 0.1198619
# Run 2 stress 0.1464915
# Run 3 stress 0.1503114
# Run 4 stress 0.1082857
# ... New best solution
# ... Procrustes: rmse 0.01787218  max resid 0.07958757
# Run 5 stress 0.1440088
# Run 6 stress 0.1083899
# ... Procrustes: rmse 0.01789053  max resid 0.07970532
# Run 7 stress 0.1082856
# ... New best solution
# ... Procrustes: rmse 8.059858e-05  max resid 0.0003636676
# ... Similar to previous best
# Run 8 stress 0.1196991
# Run 9 stress 0.1083899
# ... Procrustes: rmse 0.01783938  max resid 0.079354
# Run 10 stress 0.1084873
# ... Procrustes: rmse 0.01713061  max resid 0.0794905
# Run 11 stress 0.1196991
# Run 12 stress 0.1082858
# ... Procrustes: rmse 9.212756e-05  max resid 0.0002727516
# ... Similar to previous best
# Run 13 stress 0.119699
# Run 14 stress 0.1091857
# Run 15 stress 0.1481967
# Run 16 stress 0.1457826
# Run 17 stress 0.1196992
# Run 18 stress 0.1083899
# ... Procrustes: rmse 0.01783435  max resid 0.07938363
# Run 19 stress 0.155976
# Run 20 stress 0.1198621
# *** Solution reached
# Run 0 stress 0.09575946
# Run 1 stress 0.09840438
# Run 2 stress 0.0918364
# ... New best solution
# ... Procrustes: rmse 0.02395138  max resid 0.1151311
# Run 3 stress 0.09305461
# Run 4 stress 0.0959069
# Run 5 stress 0.1278609
# Run 6 stress 0.1108186
# Run 7 stress 0.1052367
# Run 8 stress 0.09305448
# Run 9 stress 0.1109669
# Run 10 stress 0.1284595
# Run 11 stress 0.1115861
# Run 12 stress 0.11269
# Run 13 stress 0.1272609
# Run 14 stress 0.1049346
# Run 15 stress 0.09183712
# ... Procrustes: rmse 0.0002517413  max resid 0.001036079
# ... Similar to previous best
# Run 16 stress 0.09305444
# Run 17 stress 0.09639803
# Run 18 stress 0.1244741
# Run 19 stress 0.1302358
# Run 20 stress 0.1535183
# *** Solution reached
# Run 0 stress 0.1004024
# Run 1 stress 0.1139575
# Run 2 stress 0.1048432
# Run 3 stress 0.103883
# Run 4 stress 0.09893565
# ... New best solution
# ... Procrustes: rmse 0.01893333  max resid 0.09557876
# Run 5 stress 0.09917908
# ... Procrustes: rmse 0.01148489  max resid 0.04919764
# Run 6 stress 0.1374628
# Run 7 stress 0.1318128
# Run 8 stress 0.1004024
# Run 9 stress 0.1141013
# Run 10 stress 0.1316633
# Run 11 stress 0.1180587
# Run 12 stress 0.09917911
# ... Procrustes: rmse 0.01147188  max resid 0.04914638
# Run 13 stress 0.1423316
# Run 14 stress 0.1004025
# Run 15 stress 0.09893561
# ... New best solution
# ... Procrustes: rmse 6.448532e-05  max resid 0.0002172981
# ... Similar to previous best
# Run 16 stress 0.1297748
# Run 17 stress 0.09893572
# ... Procrustes: rmse 4.288949e-05  max resid 0.0001051486
# ... Similar to previous best
# Run 18 stress 0.1126025
# Run 19 stress 0.09893561
# ... Procrustes: rmse 1.227309e-06  max resid 3.060583e-06
# ... Similar to previous best
# Run 20 stress 0.1134598
# *** Solution reached
# Run 0 stress 0.05294869
# Run 1 stress 0.05295046
# ... Procrustes: rmse 0.0009092942  max resid 0.004303849
# ... Similar to previous best
# Run 2 stress 0.05294903
# ... Procrustes: rmse 0.0007265289  max resid 0.003243718
# ... Similar to previous best
# Run 3 stress 0.05294939
# ... Procrustes: rmse 0.0007946722  max resid 0.003743564
# ... Similar to previous best
# Run 4 stress 0.05294862
# ... New best solution
# ... Procrustes: rmse 0.0006297931  max resid 0.002780301
# ... Similar to previous best
# Run 5 stress 0.05294932
# ... Procrustes: rmse 0.0002272579  max resid 0.0008364579
# ... Similar to previous best
# Run 6 stress 0.05294846
# ... New best solution
# ... Procrustes: rmse 0.0001340169  max resid 0.0004766285
# ... Similar to previous best
# Run 7 stress 0.05294772
# ... New best solution
# ... Procrustes: rmse 0.0002270369  max resid 0.001140321
# ... Similar to previous best
# Run 8 stress 0.05294814
# ... Procrustes: rmse 0.0003008035  max resid 0.001311764
# ... Similar to previous best
# Run 9 stress 0.05294867
# ... Procrustes: rmse 0.000285434  max resid 0.001397249
# ... Similar to previous best
# Run 10 stress 0.05294999
# ... Procrustes: rmse 0.0004813129  max resid 0.002402136
# ... Similar to previous best
# Run 11 stress 0.05294873
# ... Procrustes: rmse 0.000297727  max resid 0.001508744
# ... Similar to previous best
# Run 12 stress 0.05294781
# ... Procrustes: rmse 4.300537e-05  max resid 0.0001769981
# ... Similar to previous best
# Run 13 stress 0.1040318
# Run 14 stress 0.05294845
# ... Procrustes: rmse 0.0002161156  max resid 0.001094807
# ... Similar to previous best
# Run 15 stress 0.1050533
# Run 16 stress 0.05294966
# ... Procrustes: rmse 0.0004510631  max resid 0.00224221
# ... Similar to previous best
# Run 17 stress 0.05294904
# ... Procrustes: rmse 0.0003331207  max resid 0.001657545
# ... Similar to previous best
# Run 18 stress 0.05295048
# ... Procrustes: rmse 0.0005614802  max resid 0.002826895
# ... Similar to previous best
# Run 19 stress 0.1041024
# Run 20 stress 0.1040313
# *** Solution reached
# Run 0 stress 0.1083899
# Run 1 stress 0.1503123
# Run 2 stress 0.1091857
# Run 3 stress 0.1481972
# Run 4 stress 0.1434674
# Run 5 stress 0.1198821
# Run 6 stress 0.1743077
# Run 7 stress 0.1783911
# Run 8 stress 0.1198622
# Run 9 stress 0.1091857
# Run 10 stress 0.1481967
# Run 11 stress 0.1198622
# Run 12 stress 0.1196991
# Run 13 stress 0.1198821
# Run 14 stress 0.119862
# Run 15 stress 0.1559752
# Run 16 stress 0.1091857
# Run 17 stress 0.1083327
# ... New best solution
# ... Procrustes: rmse 0.01725564  max resid 0.07921239
# Run 18 stress 0.1433693
# Run 19 stress 0.1083902
# ... Procrustes: rmse 0.0172705  max resid 0.07920062
# Run 20 stress 0.1083899
# ... Procrustes: rmse 0.01724444  max resid 0.07930691
# Run 21 stress 0.1428074
# Run 22 stress 0.119862
# Run 23 stress 0.1082856
# ... New best solution
# ... Procrustes: rmse 0.003496401  max resid 0.01408294
# Run 24 stress 0.119699
# Run 25 stress 0.1196992
# Run 26 stress 0.1083327
# ... Procrustes: rmse 0.00349482  max resid 0.01410535
# Run 27 stress 0.1772782
# Run 28 stress 0.1198824
# Run 29 stress 0.1476846
# Run 30 stress 0.1083899
# ... Procrustes: rmse 0.01785556  max resid 0.07960834
# Run 31 stress 0.1091858
# Run 32 stress 0.1091857
# Run 33 stress 0.1083327
# ... Procrustes: rmse 0.003495905  max resid 0.01409348
# Run 34 stress 0.1091857
# Run 35 stress 0.1429015
# Run 36 stress 0.1465931
# Run 37 stress 0.1438554
# Run 38 stress 0.1083327
# ... Procrustes: rmse 0.003495526  max resid 0.01412765
# Run 39 stress 0.1198621
# Run 40 stress 0.1198821
# Run 41 stress 0.1084872
# ... Procrustes: rmse 0.01714664  max resid 0.07967415
# Run 42 stress 0.1198622
# Run 43 stress 0.1083899
# ... Procrustes: rmse 0.01784925  max resid 0.07953515
# Run 44 stress 0.1198621
# Run 45 stress 0.1083327
# ... Procrustes: rmse 0.003495336  max resid 0.01408006
# Run 46 stress 0.1498983
# Run 47 stress 0.1498981
# Run 48 stress 0.1091857
# Run 49 stress 0.1904683
# Run 50 stress 0.119699
# Run 51 stress 0.1083903
# ... Procrustes: rmse 0.01786738  max resid 0.0794632
# Run 52 stress 0.1494044
# Run 53 stress 0.1091857
# Run 54 stress 0.1084874
# ... Procrustes: rmse 0.01716189  max resid 0.07953576
# Run 55 stress 0.1198623
# Run 56 stress 0.3917202
# Run 57 stress 0.1463724
# Run 58 stress 0.1198824
# Run 59 stress 0.1773536
# Run 60 stress 0.1198821
# Run 61 stress 0.1196991
# Run 62 stress 0.1836809
# Run 63 stress 0.1091859
# Run 64 stress 0.1083327
# ... Procrustes: rmse 0.003498217  max resid 0.01411698
# Run 65 stress 0.1196991
# Run 66 stress 0.1091857
# Run 67 stress 0.119862
# Run 68 stress 0.1083899
# ... Procrustes: rmse 0.01785355  max resid 0.0795064
# Run 69 stress 0.1503116
# Run 70 stress 0.1196991
# Run 71 stress 0.1082856
# ... New best solution
# ... Procrustes: rmse 7.253059e-05  max resid 0.0003397872
# ... Similar to previous best
# *** Solution reached
# Run 0 stress 0.09575946
# Run 1 stress 0.1108187
# Run 2 stress 0.1072639
# Run 3 stress 0.1049659
# Run 4 stress 0.105207
# Run 5 stress 0.09305459
# ... New best solution
# ... Procrustes: rmse 0.02465093  max resid 0.1130586
# Run 6 stress 0.110798
# Run 7 stress 0.1107481
# Run 8 stress 0.09183638
# ... New best solution
# ... Procrustes: rmse 0.007552308  max resid 0.03431071
# Run 9 stress 0.1062487
# Run 10 stress 0.09649192
# Run 11 stress 0.09575939
# Run 12 stress 0.09439787
# Run 13 stress 0.09555216
# Run 14 stress 0.1052378
# Run 15 stress 0.1052086
# Run 16 stress 0.09183641
# ... Procrustes: rmse 7.596721e-05  max resid 0.0001503566
# ... Similar to previous best
# Run 17 stress 0.09575937
# Run 18 stress 0.107249
# Run 19 stress 0.1284594
# Run 20 stress 0.1952853
# *** Solution reached
# Run 0 stress 0.1004024
# Run 1 stress 0.117884
# Run 2 stress 0.09893562
# ... New best solution
# ... Procrustes: rmse 0.01890805  max resid 0.09551826
# Run 3 stress 0.1004024
# Run 4 stress 0.1316875
# Run 5 stress 0.1004024
# Run 6 stress 0.09893561
# ... New best solution
# ... Procrustes: rmse 2.816208e-05  max resid 7.728394e-05
# ... Similar to previous best
# Run 7 stress 0.1318137
# Run 8 stress 0.1053412
# Run 9 stress 0.09917921
# ... Procrustes: rmse 0.0114999  max resid 0.04921376
# Run 10 stress 0.09912165
# ... Procrustes: rmse 0.008499329  max resid 0.04277998
# Run 11 stress 0.1134598
# Run 12 stress 0.1038816
# Run 13 stress 0.1134598
# Run 14 stress 0.1363323
# Run 15 stress 0.1004024
# Run 16 stress 0.1404414
# Run 17 stress 0.1126024
# Run 18 stress 0.09893561
# ... Procrustes: rmse 7.086003e-06  max resid 1.777949e-05
# ... Similar to previous best
# Run 19 stress 0.11629
# Run 20 stress 0.112603
# *** Solution reached
# Run 0 stress 0.05294869
# Run 1 stress 0.05294787
# ... New best solution
# ... Procrustes: rmse 0.0003266749  max resid 0.001364716
# ... Similar to previous best
# Run 2 stress 0.1062448
# Run 3 stress 0.05294981
# ... Procrustes: rmse 0.0004742918  max resid 0.002322807
# ... Similar to previous best
# Run 4 stress 0.05294967
# ... Procrustes: rmse 0.0005042041  max resid 0.002448387
# ... Similar to previous best
# Run 5 stress 0.05294906
# ... Procrustes: rmse 0.0004118524  max resid 0.002025548
# ... Similar to previous best
# Run 6 stress 0.1074875
# Run 7 stress 0.05294889
# ... Procrustes: rmse 0.0004055444  max resid 0.002000906
# ... Similar to previous best
# Run 8 stress 0.05294773
# ... New best solution
# ... Procrustes: rmse 0.0001412642  max resid 0.0003671323
# ... Similar to previous best
# Run 9 stress 0.05294807
# ... Procrustes: rmse 0.000143736  max resid 0.0004821496
# ... Similar to previous best
# Run 10 stress 0.1055786
# Run 11 stress 0.05294861
# ... Procrustes: rmse 0.0003291654  max resid 0.001161036
# ... Similar to previous best
# Run 12 stress 0.0529489
# ... Procrustes: rmse 0.0002784269  max resid 0.001396662
# ... Similar to previous best
# Run 13 stress 0.05294837
# ... Procrustes: rmse 0.0002147373  max resid 0.00108231
# ... Similar to previous best
# Run 14 stress 0.1046961
# Run 15 stress 0.05294813
# ... Procrustes: rmse 0.0001040023  max resid 0.0004919565
# ... Similar to previous best
# Run 16 stress 0.1044329
# Run 17 stress 0.05294958
# ... Procrustes: rmse 0.0004321308  max resid 0.002092501
# ... Similar to previous best
# Run 18 stress 0.1040306
# Run 19 stress 0.104323
# Run 20 stress 0.05294767
# ... New best solution
# ... Procrustes: rmse 6.382342e-05  max resid 0.0003252803
# ... Similar to previous best
# *** Solution reached
# Run 0 stress 0.1083899
# Run 1 stress 0.10839
# ... Procrustes: rmse 0.0001546224  max resid 0.0004106093
# ... Similar to previous best
# Run 2 stress 0.173885
# Run 3 stress 0.1462162
# Run 4 stress 0.1083328
# ... New best solution
# ... Procrustes: rmse 0.01730902  max resid 0.07964486
# Run 5 stress 0.1091858
# Run 6 stress 0.119862
# Run 7 stress 0.1433356
# Run 8 stress 0.119699
# Run 9 stress 0.1196993
# Run 10 stress 0.1559747
# Run 11 stress 0.1196991
# Run 12 stress 0.146216
# Run 13 stress 0.149132
# Run 14 stress 0.1462783
# Run 15 stress 0.10839
# ... Procrustes: rmse 0.01732734  max resid 0.07974788
# Run 16 stress 0.1198825
# Run 17 stress 0.1435213
# Run 18 stress 0.1553754
# Run 19 stress 0.1082859
# ... New best solution
# ... Procrustes: rmse 0.003525689  max resid 0.01410687
# Run 20 stress 0.1198621
# Run 21 stress 0.1198619
# Run 22 stress 0.1091857
# Run 23 stress 0.1083328
# ... Procrustes: rmse 0.003521658  max resid 0.01413771
# Run 24 stress 0.1083327
# ... Procrustes: rmse 0.003518128  max resid 0.01417785
# Run 25 stress 0.1198822
# Run 26 stress 0.1462959
# Run 27 stress 0.1464906
# Run 28 stress 0.1196993
# Run 29 stress 0.1198619
# Run 30 stress 0.1462088
# Run 31 stress 0.1196991
# Run 32 stress 0.1198619
# Run 33 stress 0.10839
# ... Procrustes: rmse 0.01772473  max resid 0.07830992
# Run 34 stress 0.1196991
# Run 35 stress 0.1553753
# Run 36 stress 0.1198623
# Run 37 stress 0.1091858
# Run 38 stress 0.1498982
# Run 39 stress 0.14365
# Run 40 stress 0.1196993
# Run 41 stress 0.119882
# Run 42 stress 0.1559765
# Run 43 stress 0.1198828
# Run 44 stress 0.1776413
# Run 45 stress 0.1434678
# Run 46 stress 0.1434676
# Run 47 stress 0.1083899
# ... Procrustes: rmse 0.0177124  max resid 0.07835401
# Run 48 stress 0.1083327
# ... Procrustes: rmse 0.0035158  max resid 0.01421629
# Run 49 stress 0.1196992
# Run 50 stress 0.1198621
# Run 51 stress 0.1434664
# Run 52 stress 0.1082856
# ... New best solution
# ... Procrustes: rmse 0.0001538423  max resid 0.0007580655
# ... Similar to previous best
# *** Solution reached
# Run 0 stress 0.09575946
# Run 1 stress 0.0964916
# Run 2 stress 0.1264161
# Run 3 stress 0.1281126
# Run 4 stress 0.1284159
# Run 5 stress 0.1288609
# Run 6 stress 0.1072639
# Run 7 stress 0.09305465
# ... New best solution
# ... Procrustes: rmse 0.02470693  max resid 0.1131362
# Run 8 stress 0.1075327
# Run 9 stress 0.1107483
# Run 10 stress 0.09183722
# ... New best solution
# ... Procrustes: rmse 0.007575665  max resid 0.03424086
# Run 11 stress 0.09866691
# Run 12 stress 0.09639798
# Run 13 stress 0.1554345
# Run 14 stress 0.107264
# Run 15 stress 0.1283987
# Run 16 stress 0.09183638
# ... New best solution
# ... Procrustes: rmse 0.0003828713  max resid 0.001645286
# ... Similar to previous best
# Run 17 stress 0.1283942
# Run 18 stress 0.1263526
# Run 19 stress 0.1288625
# Run 20 stress 0.09549773
# *** Solution reached
# Run 0 stress 0.1004024
# Run 1 stress 0.09893565
# ... New best solution
# ... Procrustes: rmse 0.01893359  max resid 0.09558018
# Run 2 stress 0.1038583
# Run 3 stress 0.09917909
# ... Procrustes: rmse 0.01148441  max resid 0.04919411
# Run 4 stress 0.1178845
# Run 5 stress 0.2045386
# Run 6 stress 0.1198662
# Run 7 stress 0.09912169
# ... Procrustes: rmse 0.008523097  max resid 0.04290081
# Run 8 stress 0.1004024
# Run 9 stress 0.1004024
# Run 10 stress 0.1134599
# Run 11 stress 0.09893565
# ... New best solution
# ... Procrustes: rmse 6.567576e-05  max resid 0.0002284446
# ... Similar to previous best
# Run 12 stress 0.1316635
# Run 13 stress 0.1134598
# Run 14 stress 0.1004024
# Run 15 stress 0.1048425
# Run 16 stress 0.1139821
# Run 17 stress 0.1350765
# Run 18 stress 0.09893561
# ... New best solution
# ... Procrustes: rmse 5.713748e-05  max resid 0.0002314075
# ... Similar to previous best
# Run 19 stress 0.09893561
# ... New best solution
# ... Procrustes: rmse 1.827685e-05  max resid 6.806719e-05
# ... Similar to previous best
# Run 20 stress 0.1341
# *** Solution reached
# Run 0 stress 0.05294869
# Run 1 stress 0.05294834
# ... New best solution
# ... Procrustes: rmse 0.000116237  max resid 0.0003380713
# ... Similar to previous best
# Run 2 stress 0.05294873
# ... Procrustes: rmse 0.0006274549  max resid 0.002906444
# ... Similar to previous best
# Run 3 stress 0.05294774
# ... New best solution
# ... Procrustes: rmse 0.0002040182  max resid 0.0008389489
# ... Similar to previous best
# Run 4 stress 0.05294819
# ... Procrustes: rmse 0.0002709182  max resid 0.0006752651
# ... Similar to previous best
# Run 5 stress 0.05294938
# ... Procrustes: rmse 0.0004994748  max resid 0.00245665
# ... Similar to previous best
# Run 6 stress 0.05294873
# ... Procrustes: rmse 0.0004184043  max resid 0.002057959
# ... Similar to previous best
# Run 7 stress 0.1070001
# Run 8 stress 0.05294831
# ... Procrustes: rmse 0.0003545309  max resid 0.00144826
# ... Similar to previous best
# Run 9 stress 0.05294873
# ... Procrustes: rmse 0.0002340786  max resid 0.0009361825
# ... Similar to previous best
# Run 10 stress 0.05294875
# ... Procrustes: rmse 0.0004132323  max resid 0.002037324
# ... Similar to previous best
# Run 11 stress 0.0529504
# ... Procrustes: rmse 0.0006529796  max resid 0.003215912
# ... Similar to previous best
# Run 12 stress 0.1046971
# Run 13 stress 0.05294795
# ... Procrustes: rmse 8.857737e-05  max resid 0.0003581071
# ... Similar to previous best
# Run 14 stress 0.05294924
# ... Procrustes: rmse 0.0005387446  max resid 0.002676044
# ... Similar to previous best
# Run 15 stress 0.05295077
# ... Procrustes: rmse 0.0007103725  max resid 0.003516635
# ... Similar to previous best
# Run 16 stress 0.1043185
# Run 17 stress 0.05294984
# ... Procrustes: rmse 0.0006210809  max resid 0.003086784
# ... Similar to previous best
# Run 18 stress 0.0624515
# Run 19 stress 0.2326093
# Run 20 stress 0.05294827
# ... Procrustes: rmse 0.0002460799  max resid 0.0006798354
# ... Similar to previous best
# *** Solution reached
# Run 0 stress 0.1083899
# Run 1 stress 0.1082856
# ... New best solution
# ... Procrustes: rmse 0.0177931  max resid 0.07899548
# Run 2 stress 0.1560239
# Run 3 stress 0.1460169
# Run 4 stress 0.1198619
# Run 5 stress 0.1428395
# Run 6 stress 0.1457824
# Run 7 stress 0.1196991
# Run 8 stress 0.1083899
# ... Procrustes: rmse 0.01781086  max resid 0.07912186
# Run 9 stress 0.1083899
# ... Procrustes: rmse 0.01782015  max resid 0.07906489
# Run 10 stress 0.1082856
# ... Procrustes: rmse 6.078526e-05  max resid 0.0001319973
# ... Similar to previous best
# Run 11 stress 0.1462092
# Run 12 stress 0.1747404
# Run 13 stress 0.1083327
# ... Procrustes: rmse 0.003494795  max resid 0.01414197
# Run 14 stress 0.1083327
# ... Procrustes: rmse 0.003499602  max resid 0.01409597
# Run 15 stress 0.1082856
# ... New best solution
# ... Procrustes: rmse 3.720735e-05  max resid 0.0001485054
# ... Similar to previous best
# Run 16 stress 0.119699
# Run 17 stress 0.1443294
# Run 18 stress 0.1082857
# ... Procrustes: rmse 5.507058e-05  max resid 9.999173e-05
# ... Similar to previous best
# Run 19 stress 0.1197001
# Run 20 stress 0.1198821
# *** Solution reached
# Run 0 stress 0.09575946
# Run 1 stress 0.09183639
# ... New best solution
# ... Procrustes: rmse 0.02393366  max resid 0.1150927
# Run 2 stress 0.09183656
# ... Procrustes: rmse 0.0002130341  max resid 0.0007999308
# ... Similar to previous best
# Run 3 stress 0.09305444
# Run 4 stress 0.1052368
# Run 5 stress 0.09575944
# Run 6 stress 0.1249127
# Run 7 stress 0.1049346
# Run 8 stress 0.09590711
# Run 9 stress 0.1049662
# Run 10 stress 0.09305445
# Run 11 stress 0.126705
# Run 12 stress 0.09575945
# Run 13 stress 0.1052373
# Run 14 stress 0.09183648
# ... Procrustes: rmse 0.000178492  max resid 0.0006958683
# ... Similar to previous best
# Run 15 stress 0.09305482
# Run 16 stress 0.091837
# ... Procrustes: rmse 0.0002941703  max resid 0.001007918
# ... Similar to previous best
# Run 17 stress 0.1052366
# Run 18 stress 0.09183636
# ... New best solution
# ... Procrustes: rmse 9.084133e-05  max resid 0.0003913772
# ... Similar to previous best
# Run 19 stress 0.1052368
# Run 20 stress 0.09183636
# ... New best solution
# ... Procrustes: rmse 5.040583e-05  max resid 0.000212176
# ... Similar to previous best
# *** Solution reached
# Run 0 stress 0.1004024
# Run 1 stress 0.09893569
# ... New best solution
# ... Procrustes: rmse 0.0189416  max resid 0.09561897
# Run 2 stress 0.1310676
# Run 3 stress 0.09917909
# ... Procrustes: rmse 0.01150557  max resid 0.04929076
# Run 4 stress 0.09893561
# ... New best solution
# ... Procrustes: rmse 7.511309e-05  max resid 0.000225796
# ... Similar to previous best
# Run 5 stress 0.09912166
# ... Procrustes: rmse 0.008492447  max resid 0.0427423
# Run 6 stress 0.09917908
# ... Procrustes: rmse 0.01147985  max resid 0.04917512
# Run 7 stress 0.09917908
# ... Procrustes: rmse 0.01148059  max resid 0.0491771
# Run 8 stress 0.09917909
# ... Procrustes: rmse 0.0114812  max resid 0.04917931
# Run 9 stress 0.09893561
# ... New best solution
# ... Procrustes: rmse 1.500077e-05  max resid 3.417497e-05
# ... Similar to previous best
# Run 10 stress 0.09912181
# ... Procrustes: rmse 0.008555155  max resid 0.04308725
# Run 11 stress 0.09917911
# ... Procrustes: rmse 0.01149068  max resid 0.04920732
# Run 12 stress 0.1352351
# Run 13 stress 0.1004024
# Run 14 stress 0.1126024
# Run 15 stress 0.1053413
# Run 16 stress 0.2363565
# Run 17 stress 0.139688
# Run 18 stress 0.1355637
# Run 19 stress 0.1374758
# Run 20 stress 0.1141012
# *** Solution reached
# Run 0 stress 0.05294869
# Run 1 stress 0.05294783
# ... New best solution
# ... Procrustes: rmse 0.0004225933  max resid 0.001623499
# ... Similar to previous best
# Run 2 stress 0.05295079
# ... Procrustes: rmse 0.0005923876  max resid 0.003033443
# ... Similar to previous best
# Run 3 stress 0.05294995
# ... Procrustes: rmse 0.0004390104  max resid 0.002218446
# ... Similar to previous best
# Run 4 stress 0.1050554
# Run 5 stress 0.05294807
# ... Procrustes: rmse 0.000294535  max resid 0.001126501
# ... Similar to previous best
# Run 6 stress 0.0529479
# ... Procrustes: rmse 0.0001373439  max resid 0.0004951215
# ... Similar to previous best
# Run 7 stress 0.05294777
# ... New best solution
# ... Procrustes: rmse 0.0001246983  max resid 0.0004494662
# ... Similar to previous best
# Run 8 stress 0.05294971
# ... Procrustes: rmse 0.0005403102  max resid 0.0027229
# ... Similar to previous best
# Run 9 stress 0.1046976
# Run 10 stress 0.05294907
# ... Procrustes: rmse 0.0004338536  max resid 0.002179211
# ... Similar to previous best
# Run 11 stress 0.05294781
# ... Procrustes: rmse 0.0001383997  max resid 0.0006325545
# ... Similar to previous best
# Run 12 stress 0.05294784
# ... Procrustes: rmse 0.0001573655  max resid 0.0005660321
# ... Similar to previous best
# Run 13 stress 0.05294883
# ... Procrustes: rmse 0.0004018854  max resid 0.002022158
# ... Similar to previous best
# Run 14 stress 0.05294837
# ... Procrustes: rmse 0.0002160186  max resid 0.0005134343
# ... Similar to previous best
# Run 15 stress 0.05295766
# ... Procrustes: rmse 0.001171213  max resid 0.005286868
# ... Similar to previous best
# Run 16 stress 0.0529496
# ... Procrustes: rmse 0.000528507  max resid 0.002631755
# ... Similar to previous best
# Run 17 stress 0.1046979
# Run 18 stress 0.1057297
# Run 19 stress 0.05294893
# ... Procrustes: rmse 0.0004180239  max resid 0.00208896
# ... Similar to previous best
# Run 20 stress 0.1062432
# *** Solution reached
# Run 0 stress 0.1083899
# Run 1 stress 0.1083899
# ... New best solution
# ... Procrustes: rmse 9.62724e-05  max resid 0.0002403597
# ... Similar to previous best
# Run 2 stress 0.1198619
# Run 3 stress 0.119862
# Run 4 stress 0.1428069
# Run 5 stress 0.1198828
# Run 6 stress 0.1491047
# Run 7 stress 0.1082856
# ... New best solution
# ... Procrustes: rmse 0.01782787  max resid 0.07903865
# Run 8 stress 0.1462166
# Run 9 stress 0.119699
# Run 10 stress 0.1083899
# ... Procrustes: rmse 0.01783542  max resid 0.07927507
# Run 11 stress 0.1091857
# Run 12 stress 0.1498988
# Run 13 stress 0.1196991
# Run 14 stress 0.1083899
# ... Procrustes: rmse 0.01783031  max resid 0.07923992
# Run 15 stress 0.1457828
# Run 16 stress 0.1198821
# Run 17 stress 0.1082856
# ... Procrustes: rmse 3.045585e-05  max resid 6.492801e-05
# ... Similar to previous best
# Run 18 stress 0.1084873
# ... Procrustes: rmse 0.01711231  max resid 0.07951905
# Run 19 stress 0.1558802
# Run 20 stress 0.1083899
# ... Procrustes: rmse 0.01781154  max resid 0.07925489
# *** Solution reached
# Run 0 stress 0.09575946
# Run 1 stress 0.1108193
# Run 2 stress 0.1075324
# Run 3 stress 0.1506584
# Run 4 stress 0.1237832
# Run 5 stress 0.1115999
# Run 6 stress 0.09183644
# ... New best solution
# ... Procrustes: rmse 0.02397643  max resid 0.1151792
# Run 7 stress 0.105237
# Run 8 stress 0.1278604
# Run 9 stress 0.1062487
# Run 10 stress 0.09305454
# Run 11 stress 0.0918368
# ... Procrustes: rmse 0.0002011485  max resid 0.0007413982
# ... Similar to previous best
# Run 12 stress 0.1258079
# Run 13 stress 0.1052367
# Run 14 stress 0.127261
# Run 15 stress 0.1062488
# Run 16 stress 0.1238647
# Run 17 stress 0.129787
# Run 18 stress 0.09183639
# ... New best solution
# ... Procrustes: rmse 0.0001091714  max resid 0.0004279726
# ... Similar to previous best
# Run 19 stress 0.09183682
# ... Procrustes: rmse 0.000298635  max resid 0.001295589
# ... Similar to previous best
# Run 20 stress 0.1049669
# *** Solution reached
# Run 0 stress 0.1004024
# Run 1 stress 0.1139576
# Run 2 stress 0.1168093
# Run 3 stress 0.1126025
# Run 4 stress 0.1175557
# Run 5 stress 0.1139577
# Run 6 stress 0.09917909
# ... New best solution
# ... Procrustes: rmse 0.02346447  max resid 0.09394793
# Run 7 stress 0.1048432
# Run 8 stress 0.1139579
# Run 9 stress 0.1199567
# Run 10 stress 0.1168391
# Run 11 stress 0.1355631
# Run 12 stress 0.1194659
# Run 13 stress 0.1052958
# Run 14 stress 0.1126027
# Run 15 stress 0.1048431
# Run 16 stress 0.1376871
# Run 17 stress 0.1126024
# Run 18 stress 0.1346697
# Run 19 stress 0.1039086
# Run 20 stress 0.1004024
# Run 21 stress 0.1316628
# Run 22 stress 0.1380548
# Run 23 stress 0.1169654
# Run 24 stress 0.1053414
# Run 25 stress 0.117884
# Run 26 stress 0.1038013
# Run 27 stress 0.0991791
# ... Procrustes: rmse 1.6148e-05  max resid 5.463017e-05
# ... Similar to previous best
# *** Solution reached
# Run 0 stress 0.05294869
# Run 1 stress 0.05294838
# ... New best solution
# ... Procrustes: rmse 0.0005597986  max resid 0.0026297
# ... Similar to previous best
# Run 2 stress 0.05294902
# ... Procrustes: rmse 0.0001628154  max resid 0.0007413404
# ... Similar to previous best
# Run 3 stress 0.05294913
# ... Procrustes: rmse 0.0001927757  max resid 0.0009009418
# ... Similar to previous best
# Run 4 stress 0.05294796
# ... New best solution
# ... Procrustes: rmse 0.0001092879  max resid 0.0003966747
# ... Similar to previous best
# Run 5 stress 0.1040317
# Run 6 stress 0.104102
# Run 7 stress 0.1046959
# Run 8 stress 0.05294917
# ... Procrustes: rmse 0.0002013076  max resid 0.0009915627
# ... Similar to previous best
# Run 9 stress 0.05294908
# ... Procrustes: rmse 0.0002572787  max resid 0.001304009
# ... Similar to previous best
# Run 10 stress 0.1055801
# Run 11 stress 0.0529494
# ... Procrustes: rmse 0.0003068157  max resid 0.001455631
# ... Similar to previous best
# Run 12 stress 0.05294771
# ... New best solution
# ... Procrustes: rmse 0.0001166327  max resid 0.0006015964
# ... Similar to previous best
# Run 13 stress 0.1044334
# Run 14 stress 0.05294883
# ... Procrustes: rmse 0.0003052454  max resid 0.0009568816
# ... Similar to previous best
# Run 15 stress 0.1046964
# Run 16 stress 0.05294802
# ... Procrustes: rmse 0.0002671592  max resid 0.0011625
# ... Similar to previous best
# Run 17 stress 0.05294987
# ... Procrustes: rmse 0.000494406  max resid 0.002507363
# ... Similar to previous best
# Run 18 stress 0.05294806
# ... Procrustes: rmse 0.0002771939  max resid 0.001198485
# ... Similar to previous best
# Run 19 stress 0.1050547
# Run 20 stress 0.1064079
# *** Solution reached
# Run 0 stress 0.1083899
# Run 1 stress 0.1198622
# Run 2 stress 0.119882
# Run 3 stress 0.1462165
# Run 4 stress 0.1083327
# ... New best solution
# ... Procrustes: rmse 0.01718771  max resid 0.07880711
# Run 5 stress 0.1476854
# Run 6 stress 0.1498983
# Run 7 stress 0.1091857
# Run 8 stress 0.1462088
# Run 9 stress 0.1196992
# Run 10 stress 0.1434676
# Run 11 stress 0.1091857
# Run 12 stress 0.1084872
# ... Procrustes: rmse 0.01731162  max resid 0.0790273
# Run 13 stress 0.1433702
# Run 14 stress 0.1083327
# ... Procrustes: rmse 0.0001472549  max resid 0.0007182619
# ... Similar to previous best
# Run 15 stress 0.1196991
# Run 16 stress 0.1481971
# Run 17 stress 0.1082856
# ... New best solution
# ... Procrustes: rmse 0.003506257  max resid 0.01399492
# Run 18 stress 0.119699
# Run 19 stress 0.1505903
# Run 20 stress 0.1498982
# Run 21 stress 0.1082856
# ... New best solution
# ... Procrustes: rmse 3.584946e-05  max resid 6.298352e-05
# ... Similar to previous best
# *** Solution reached
# Run 0 stress 0.09575946
# Run 1 stress 0.09183648
# ... New best solution
# ... Procrustes: rmse 0.0239364  max resid 0.115093
# Run 2 stress 0.09649187
# Run 3 stress 0.1524143
# Run 4 stress 0.09183667
# ... Procrustes: rmse 0.0001800041  max resid 0.0005445276
# ... Similar to previous best
# Run 5 stress 0.3933695
# Run 6 stress 0.1075347
# Run 7 stress 0.1062839
# Run 8 stress 0.1283978
# Run 9 stress 0.09639798
# Run 10 stress 0.1059512
# Run 11 stress 0.1052369
# Run 12 stress 0.1288606
# Run 13 stress 0.09183702
# ... Procrustes: rmse 0.000258253  max resid 0.0006522621
# ... Similar to previous best
# Run 14 stress 0.09575935
# Run 15 stress 0.09488926
# Run 16 stress 0.1052367
# Run 17 stress 0.09639799
# Run 18 stress 0.1072639
# Run 19 stress 0.09590712
# Run 20 stress 0.1256193
# *** Solution reached
# Run 0 stress 0.1004024
# Run 1 stress 0.1126027
# Run 2 stress 0.1126025
# Run 3 stress 0.1141017
# Run 4 stress 0.1318128
# Run 5 stress 0.09917917
# ... New best solution
# ... Procrustes: rmse 0.02349322  max resid 0.09398946
# Run 6 stress 0.2743786
# Run 7 stress 0.1168094
# Run 8 stress 0.1344064
# Run 9 stress 0.1134603
# Run 10 stress 0.1126027
# Run 11 stress 0.1004024
# Run 12 stress 0.1126026
# Run 13 stress 0.1004024
# Run 14 stress 0.1004024
# Run 15 stress 0.131813
# Run 16 stress 0.1359301
# Run 17 stress 0.1366896
# Run 18 stress 0.1139581
# Run 19 stress 0.1316629
# Run 20 stress 0.1126026
# Run 21 stress 0.1369916
# Run 22 stress 0.137723
# Run 23 stress 0.1004024
# Run 24 stress 0.1141013
# Run 25 stress 0.1004024
# Run 26 stress 0.117884
# Run 27 stress 0.09917909
# ... New best solution
# ... Procrustes: rmse 9.370177e-05  max resid 0.000230823
# ... Similar to previous best
# *** Solution reached
# [1] "Blinded_Store"
# [1] "ID"
# [1] "City"
# [1] "Treatment"
# [1] "Packaging"
# Run 0 stress 8.129734e-05
# Run 1 stress 0.0001954705
# ... Procrustes: rmse 0.08209444  max resid 0.1504316
# Run 2 stress 9.947938e-05
# ... Procrustes: rmse 0.08494015  max resid 0.1510116
# Run 3 stress 0.0002000285
# ... Procrustes: rmse 0.08928873  max resid 0.1905175
# Run 4 stress 0.0005689305
# ... Procrustes: rmse 0.09401429  max resid 0.1899418
# Run 5 stress 0.0001312247
# ... Procrustes: rmse 0.09611695  max resid 0.1884885
# Run 6 stress 9.863889e-05
# ... Procrustes: rmse 0.09776027  max resid 0.1912478
# Run 7 stress 9.969468e-05
# ... Procrustes: rmse 0.09787892  max resid 0.1690345
# Run 8 stress 0.0001074906
# ... Procrustes: rmse 0.09000773  max resid 0.1462895
# Run 9 stress 0.0001430263
# ... Procrustes: rmse 0.07496941  max resid 0.1633643
# Run 10 stress 0.0004988461
# ... Procrustes: rmse 0.09942254  max resid 0.2029733
# Run 11 stress 9.792895e-05
# ... Procrustes: rmse 0.09789608  max resid 0.1523879
# Run 12 stress 0.0001193796
# ... Procrustes: rmse 0.09339179  max resid 0.1640974
# Run 13 stress 9.458001e-05
# ... Procrustes: rmse 0.08448906  max resid 0.1603006
# Run 14 stress 0.0001107432
# ... Procrustes: rmse 0.01778618  max resid 0.03491941
# Run 15 stress 9.957652e-05
# ... Procrustes: rmse 0.07712582  max resid 0.1612488
# Run 16 stress 9.949075e-05
# ... Procrustes: rmse 0.02299969  max resid 0.04553171
# Run 17 stress 0.0003848087
# ... Procrustes: rmse 0.07441789  max resid 0.1499157
# Run 18 stress 0.0001158584
# ... Procrustes: rmse 0.08551922  max resid 0.1474049
# Run 19 stress 9.840286e-05
# ... Procrustes: rmse 0.07186227  max resid 0.130581
# Run 20 stress 9.912847e-05
# ... Procrustes: rmse 0.1006482  max resid 0.1994071
# Run 21 stress 0.0001107355
# ... Procrustes: rmse 0.06510759  max resid 0.1475894
# Run 22 stress 0.0001468326
# ... Procrustes: rmse 0.09824368  max resid 0.174889
# Run 23 stress 0.0001034426
# ... Procrustes: rmse 0.09233372  max resid 0.1937596
# Run 24 stress 0.000125428
# ... Procrustes: rmse 0.01785887  max resid 0.03504661
# Run 25 stress 9.943852e-05
# ... Procrustes: rmse 0.09863987  max resid 0.1729159
# Run 26 stress 9.578575e-05
# ... Procrustes: rmse 0.007772717  max resid 0.01654718
# Run 27 stress 0.0001955098
# ... Procrustes: rmse 0.01825429  max resid 0.03591066
# Run 28 stress 0.0003643267
# ... Procrustes: rmse 0.09504614  max resid 0.1932185
# Run 29 stress 9.948867e-05
# ... Procrustes: rmse 0.09881815  max resid 0.1910391
# Run 30 stress 9.838038e-05
# ... Procrustes: rmse 0.08369511  max resid 0.132137
# Run 31 stress 0.0004498852
# ... Procrustes: rmse 0.1005341  max resid 0.2042946
# Run 32 stress 0.0006058581
# Run 33 stress 0.0001116474
# ... Procrustes: rmse 0.01780275  max resid 0.03494417
# Run 34 stress 0.0003498716
# ... Procrustes: rmse 0.1001702  max resid 0.2032936
# Run 35 stress 9.789155e-05
# ... Procrustes: rmse 0.03849024  max resid 0.07075014
# Run 36 stress 9.93031e-05
# ... Procrustes: rmse 0.0937955  max resid 0.1630494
# Run 37 stress 9.784865e-05
# ... Procrustes: rmse 0.01833626  max resid 0.03794893
# Run 38 stress 0.0003563222
# ... Procrustes: rmse 0.1007348  max resid 0.2024734
# Run 39 stress 0.0001305413
# ... Procrustes: rmse 0.08663072  max resid 0.1570139
# Run 40 stress 9.95213e-05
# ... Procrustes: rmse 0.09406516  max resid 0.1841164
# Run 41 stress 9.963232e-05
# ... Procrustes: rmse 0.09744992  max resid 0.1970407
# Run 42 stress 9.784942e-05
# ... Procrustes: rmse 0.09421803  max resid 0.1548118
# Run 43 stress 9.737926e-05
# ... Procrustes: rmse 0.09584769  max resid 0.1621497
# Run 44 stress 0.0002082508
# ... Procrustes: rmse 0.09412091  max resid 0.1970241
# Run 45 stress 9.887245e-05
# ... Procrustes: rmse 0.09719948  max resid 0.166899
# Run 46 stress 9.564418e-05
# ... Procrustes: rmse 0.07036036  max resid 0.1143514
# Run 47 stress 0.0003222269
# ... Procrustes: rmse 0.06502156  max resid 0.1550651
# Run 48 stress 9.86285e-05
# ... Procrustes: rmse 0.09381486  max resid 0.1583559
# Run 49 stress 9.818638e-05
# ... Procrustes: rmse 0.07174461  max resid 0.1673249
# Run 50 stress 9.999323e-05
# ... Procrustes: rmse 0.0965942  max resid 0.1755103
# Run 51 stress 0.0003564604
# ... Procrustes: rmse 0.09486192  max resid 0.1923099
# Run 52 stress 9.893079e-05
# ... Procrustes: rmse 0.09526659  max resid 0.1777584
# Run 53 stress 9.963982e-05
# ... Procrustes: rmse 0.0897452  max resid 0.174505
# Run 54 stress 0.0008239665
# Run 55 stress 9.802252e-05
# ... Procrustes: rmse 0.0987371  max resid 0.1788381
# Run 56 stress 9.890115e-05
# ... Procrustes: rmse 0.09963174  max resid 0.1862606
# Run 57 stress 9.98952e-05
# ... Procrustes: rmse 0.09160638  max resid 0.1565689
# Run 58 stress 0.0001032433
# ... Procrustes: rmse 0.09686333  max resid 0.1654546
# Run 59 stress 9.946932e-05
# ... Procrustes: rmse 0.08609999  max resid 0.1577051
# Run 60 stress 0.0004818989
# ... Procrustes: rmse 0.07645898  max resid 0.1365237
# Run 61 stress 9.926956e-05
# ... Procrustes: rmse 0.09778859  max resid 0.1906652
# Run 62 stress 0.0001537324
# ... Procrustes: rmse 0.01802693  max resid 0.03540938
# Run 63 stress 0.0007419397
# Run 64 stress 0.0002025102
# ... Procrustes: rmse 0.08971423  max resid 0.1784006
# Run 65 stress 0.0001281055
# ... Procrustes: rmse 0.01786426  max resid 0.03505648
# Run 66 stress 0.0001677583
# ... Procrustes: rmse 0.0747602  max resid 0.1373695
# Run 67 stress 0.000475221
# ... Procrustes: rmse 0.0751851  max resid 0.1532544
# Run 68 stress 0.0006888302
# Run 69 stress 0.0003035777
# ... Procrustes: rmse 0.06098618  max resid 0.1003125
# Run 70 stress 0.0004883195
# ... Procrustes: rmse 0.09277398  max resid 0.1907673
# Run 71 stress 0.001000075
# Run 72 stress 9.667499e-05
# ... Procrustes: rmse 0.09026091  max resid 0.1829885
# Run 73 stress 0.0009417441
# Run 74 stress 0.0004317166
# ... Procrustes: rmse 0.09849426  max resid 0.2018526
# Run 75 stress 0.0001983733
# ... Procrustes: rmse 0.09590339  max resid 0.1488847
# Run 76 stress 0.0001258706
# ... Procrustes: rmse 0.01788021  max resid 0.03510128
# Run 77 stress 9.797365e-05
# ... Procrustes: rmse 0.08970567  max resid 0.1498238
# Run 78 stress 9.95895e-05
# ... Procrustes: rmse 0.09834719  max resid 0.1583721
# Run 79 stress 9.994173e-05
# ... Procrustes: rmse 0.09715909  max resid 0.1944902
# Run 80 stress 9.811604e-05
# ... Procrustes: rmse 0.04965  max resid 0.09506331
# Run 81 stress 0.0001683456
# ... Procrustes: rmse 0.01809688  max resid 0.03555162
# Run 82 stress 0.0001408657
# ... Procrustes: rmse 0.09872895  max resid 0.1929079
# Run 83 stress 9.625992e-05
# ... Procrustes: rmse 0.003012438  max resid 0.006175362
# ... Similar to previous best
# *** Solution reached
# Warning message in metaMDS(t_data, autotransform = F, trymax = 100, stratmax = 0.999999):
# “stress is (nearly) zero: you may have insufficient data”
# Run 0 stress 0.03259701
# Run 1 stress 0.0315596
# ... New best solution
# ... Procrustes: rmse 0.03099119  max resid 0.100968
# Run 2 stress 0.03259773
# Run 3 stress 0.1037968
# Run 4 stress 0.03155898
# ... New best solution
# ... Procrustes: rmse 0.0002301111  max resid 0.0006640486
# ... Similar to previous best
# Run 5 stress 0.03155946
# ... Procrustes: rmse 0.0001879878  max resid 0.000542174
# ... Similar to previous best
# Run 6 stress 0.03155916
# ... Procrustes: rmse 9.257255e-05  max resid 0.0002696492
# ... Similar to previous best
# Run 7 stress 0.03259731
# Run 8 stress 0.03259748
# Run 9 stress 0.1037974
# Run 10 stress 0.03155928
# ... Procrustes: rmse 0.0001394016  max resid 0.0003916113
# ... Similar to previous best
# Run 11 stress 0.03155942
# ... Procrustes: rmse 0.0001818523  max resid 0.0005252865
# ... Similar to previous best
# Run 12 stress 0.03155957
# ... Procrustes: rmse 0.0002228693  max resid 0.0006433603
# ... Similar to previous best
# Run 13 stress 0.03155927
# ... Procrustes: rmse 0.0001325593  max resid 0.0003849449
# ... Similar to previous best
# Run 14 stress 0.03259697
# Run 15 stress 0.03155944
# ... Procrustes: rmse 0.0001853266  max resid 0.0005389134
# ... Similar to previous best
# Run 16 stress 0.03155932
# ... Procrustes: rmse 0.0001551331  max resid 0.0004460779
# ... Similar to previous best
# Run 17 stress 0.03259709
# Run 18 stress 0.03155897
# ... New best solution
# ... Procrustes: rmse 0.0001646387  max resid 0.000480944
# ... Similar to previous best
# Run 19 stress 0.03155906
# ... Procrustes: rmse 6.11927e-05  max resid 0.0001785164
# ... Similar to previous best
# Run 20 stress 0.03155896
# ... New best solution
# ... Procrustes: rmse 0.0001077293  max resid 0.0003002204
# ... Similar to previous best
# *** Solution reached
# Run 0 stress 0.03853193
# Run 1 stress 0.03853185
# ... New best solution
# ... Procrustes: rmse 0.0004417461  max resid 0.0009027812
# ... Similar to previous best
# Run 2 stress 0.03871637
# ... Procrustes: rmse 0.04804509  max resid 0.1421458
# Run 3 stress 0.03853168
# ... New best solution
# ... Procrustes: rmse 0.0003299143  max resid 0.0006840451
# ... Similar to previous best
# Run 4 stress 0.1038727
# Run 5 stress 0.03871644
# ... Procrustes: rmse 0.04797154  max resid 0.1419422
# Run 6 stress 0.03853188
# ... Procrustes: rmse 0.0003397999  max resid 0.0006950861
# ... Similar to previous best
# Run 7 stress 0.03853164
# ... New best solution
# ... Procrustes: rmse 2.756037e-05  max resid 5.450096e-05
# ... Similar to previous best
# Run 8 stress 0.03853192
# ... Procrustes: rmse 0.0001439359  max resid 0.0002980426
# ... Similar to previous best
# Run 9 stress 0.03853229
# ... Procrustes: rmse 0.0002219111  max resid 0.0004381303
# ... Similar to previous best
# Run 10 stress 0.03853173
# ... Procrustes: rmse 5.67281e-05  max resid 0.0001203088
# ... Similar to previous best
# Run 11 stress 0.0387166
# ... Procrustes: rmse 0.04797445  max resid 0.1420041
# Run 12 stress 0.03871655
# ... Procrustes: rmse 0.04794546  max resid 0.1420065
# Run 13 stress 0.03853182
# ... Procrustes: rmse 0.0001053341  max resid 0.0002132492
# ... Similar to previous best
# Run 14 stress 0.03853172
# ... Procrustes: rmse 6.072169e-05  max resid 0.0001307685
# ... Similar to previous best
# Run 15 stress 0.03853173
# ... Procrustes: rmse 6.156855e-05  max resid 0.000194351
# ... Similar to previous best
# Run 16 stress 0.03853167
# ... Procrustes: rmse 0.0001777762  max resid 0.0003746416
# ... Similar to previous best
# Run 17 stress 0.03871631
# ... Procrustes: rmse 0.04797054  max resid 0.1419466
# Run 18 stress 0.1070979
# Run 19 stress 0.03871744
# ... Procrustes: rmse 0.04792324  max resid 0.1420113
# Run 20 stress 0.03853198
# ... Procrustes: rmse 0.0003520102  max resid 0.0007274734
# ... Similar to previous best
# *** Solution reached
# Run 0 stress 0.04142017
# Run 1 stress 0.114018
# Run 2 stress 0.04141627
# ... New best solution
# ... Procrustes: rmse 0.002400296  max resid 0.006397748
# ... Similar to previous best
# Run 3 stress 0.03898115
# ... New best solution
# ... Procrustes: rmse 0.03818278  max resid 0.1181948
# Run 4 stress 0.1174577
# Run 5 stress 0.03898123
# ... Procrustes: rmse 0.0001533176  max resid 0.0003870162
# ... Similar to previous best
# Run 6 stress 0.0396042
# Run 7 stress 0.1653846
# Run 8 stress 0.221817
# ...
# Run 1 stress 0.1073842
# Run 2 stress 0.09140777
# ... New best solution
# ... Procrustes: rmse 1.65813e-05  max resid 4.144968e-05
# ... Similar to previous best
# Run 3 stress 0.1453292
# Run 4 stress 0.1099112
# Run 5 stress 0.1337869
# Run 6 stress 0.09140782
# ... Procrustes: rmse 7.125159e-05  max resid 0.0001931183
# ... Similar to previous best
# Run 7 stress 0.09140794
# ... Procrustes: rmse 0.0001690411  max resid 0.0004685459
# ... Similar to previous best
# Run 8 stress 0.09519631
# Run 9 stress 0.09519606
# Run 10 stress 0.09140778
# ... Procrustes: rmse 6.609175e-05  max resid 0.0001822578
# ... Similar to previous best
# Run 11 stress 0.09140783
# ... Procrustes: rmse 0.0001316957  max resid 0.0003562937
# ... Similar to previous best
# Run 12 stress 0.09140777
# ... Procrustes: rmse 5.537559e-05  max resid 0.00014476
# ... Similar to previous best
# Run 13 stress 0.09519601
# Run 14 stress 0.1073841
# Run 15 stress 0.095196
# Run 16 stress 0.1073841
# Run 17 stress 0.1073842
# Run 18 stress 0.1099112
# Run 19 stress 0.09140781
# ... Procrustes: rmse 7.24941e-05  max resid 0.0001939489
# ... Similar to previous best
# Run 20 stress 0.1099113
# *** Solution reached
# Run 0 stress 0.08711937
# Run 1 stress 0.08711935
# ... New best solution
# ... Procrustes: rmse 5.079582e-05  max resid 0.0001265813
# ... Similar to previous best
# Run 2 stress 0.0871195
# ... Procrustes: rmse 0.000130709  max resid 0.0002823725
# ... Similar to previous best
# Run 3 stress 0.0907241
# Run 4 stress 0.1041491
# Run 5 stress 0.08711936
# ... Procrustes: rmse 4.949933e-05  max resid 0.0001098451
# ... Similar to previous best
# Run 6 stress 0.08711936
# ... Procrustes: rmse 2.45535e-05  max resid 6.01824e-05
# ... Similar to previous best
# Run 7 stress 0.09072425
# Run 8 stress 0.09072415
# Run 9 stress 0.08711936
# ... Procrustes: rmse 8.997904e-05  max resid 0.0001792618
# ... Similar to previous best
# Run 10 stress 0.1017003
# Run 11 stress 0.08711935
# ... New best solution
# ... Procrustes: rmse 5.950809e-05  max resid 0.0001328143
# ... Similar to previous best
# Run 12 stress 0.1041487
# Run 13 stress 0.0907241
# Run 14 stress 0.09072414
# Run 15 stress 0.09072411
# Run 16 stress 0.09072417
# Run 17 stress 0.1017008
# Run 18 stress 0.104149
# Run 19 stress 0.1017002
# Run 20 stress 0.1327575
# *** Solution reached
# Run 0 stress 0.0520006
# Run 1 stress 0.05811202
# Run 2 stress 0.05200046
# ... New best solution
# ... Procrustes: rmse 6.116673e-05  max resid 0.0001469219
# ... Similar to previous best
# Run 3 stress 0.0520985
# ... Procrustes: rmse 0.08547745  max resid 0.2581788
# Run 4 stress 0.05083211
# ... New best solution
# ... Procrustes: rmse 0.02265779  max resid 0.07242057
# Run 5 stress 0.05200055
# Run 6 stress 0.05209823
# Run 7 stress 0.05877002
# Run 8 stress 0.05200046
# Run 9 stress 0.0580853
# Run 10 stress 0.05811212
# Run 11 stress 0.05209904
# Run 12 stress 0.0575165
# Run 13 stress 0.05209821
# Run 14 stress 0.05033103
# ... New best solution
# ... Procrustes: rmse 0.08562588  max resid 0.25464
# Run 15 stress 0.05808422
# Run 16 stress 0.05083211
# Run 17 stress 0.0587701
# Run 18 stress 0.05877002
# Run 19 stress 0.05811254
# Run 20 stress 0.05083213
# Run 21 stress 0.0520005
# Run 22 stress 0.05033095
# ... New best solution
# ... Procrustes: rmse 2.952351e-05  max resid 5.886663e-05
# ... Similar to previous best
# *** Solution reached
# Default value being used.
# Default value being used.
# Default value being used.
# Default value being used.
# Default value being used.
# Default value being used.
# Default value being used.
# Default value being used.
# Default value being used.
# Default value being used.
# Default value being used.
# Default value being used.
# Default value being used.
# Run 0 stress 0.05583291
# Run 1 stress 0.05766619
# Run 2 stress 0.05827959
# Run 3 stress 0.06373314
# Run 4 stress 0.05765914
# Run 5 stress 0.08488454
# Run 6 stress 0.07136112
# Run 7 stress 0.07200121
# Run 8 stress 0.0843816
# Run 9 stress 0.07199787
# Run 10 stress 0.08585515
# Run 11 stress 0.08244102
# Run 12 stress 0.05827864
# Run 13 stress 0.05766402
# Run 14 stress 0.09565625
# Run 15 stress 0.06373337
# Run 16 stress 0.0558324
# ... New best solution
# ... Procrustes: rmse 0.0002554359  max resid 0.0008217513
# ... Similar to previous best
# Run 17 stress 0.09580433
# Run 18 stress 0.05827868
# Run 19 stress 0.07021544
# Run 20 stress 0.05583238
# ... New best solution
# ... Procrustes: rmse 4.728187e-05  max resid 0.0001584189
# ... Similar to previous best
# *** Solution reached
# Run 0 stress 0.08882168
# Run 1 stress 0.08882184
# ... Procrustes: rmse 5.367453e-05  max resid 0.0001894289
# ... Similar to previous best
# Run 2 stress 0.08882169
# ... Procrustes: rmse 2.631286e-05  max resid 0.0001256184
# ... Similar to previous best
# Run 3 stress 0.08882171
# ... Procrustes: rmse 5.387063e-05  max resid 0.0002568958
# ... Similar to previous best
# Run 4 stress 0.08882168
# ... New best solution
# ... Procrustes: rmse 1.893267e-05  max resid 8.3133e-05
# ... Similar to previous best
# Run 5 stress 0.08882168
# ... New best solution
# ... Procrustes: rmse 1.251439e-05  max resid 4.474273e-05
# ... Similar to previous best
# Run 6 stress 0.08882168
# ... Procrustes: rmse 4.292457e-06  max resid 1.339002e-05
# ... Similar to previous best
# Run 7 stress 0.1712709
# Run 8 stress 0.08882179
# ... Procrustes: rmse 8.729824e-05  max resid 0.0003559811
# ... Similar to previous best
# Run 9 stress 0.1711128
# Run 10 stress 0.0888217
# ... Procrustes: rmse 3.546952e-05  max resid 0.0001507292
# ... Similar to previous best
# Run 11 stress 0.08882171
# ... Procrustes: rmse 1.473178e-05  max resid 5.748638e-05
# ... Similar to previous best
# Run 12 stress 0.1435173
# Run 13 stress 0.08882169
# ... Procrustes: rmse 1.289346e-05  max resid 4.327375e-05
# ... Similar to previous best
# Run 14 stress 0.08882168
# ... New best solution
# ... Procrustes: rmse 1.02675e-05  max resid 4.018987e-05
# ... Similar to previous best
# Run 15 stress 0.152102
# Run 16 stress 0.1519663
# Run 17 stress 0.08882168
# ... Procrustes: rmse 1.899608e-05  max resid 8.323919e-05
# ... Similar to previous best
# Run 18 stress 0.08882174
# ... Procrustes: rmse 5.14536e-05  max resid 0.0001965543
# ... Similar to previous best
# Run 19 stress 0.08882168
# ... Procrustes: rmse 1.789602e-05  max resid 6.762754e-05
# ... Similar to previous best
# Run 20 stress 0.08882168
# ... Procrustes: rmse 7.619871e-06  max resid 2.596137e-05
# ... Similar to previous best
# *** Solution reached
# Run 0 stress 0.03282034
# Run 1 stress 0.03282043
# ... Procrustes: rmse 2.957317e-05  max resid 7.024459e-05
# ... Similar to previous best
# Run 2 stress 0.03282016
# ... New best solution
# ... Procrustes: rmse 0.0005715641  max resid 0.001401925
# ... Similar to previous best
# Run 3 stress 0.03282037
# ... Procrustes: rmse 7.045523e-05  max resid 0.0001738201
# ... Similar to previous best
# Run 4 stress 0.03281986
# ... New best solution
# ... Procrustes: rmse 0.0001982271  max resid 0.0004763576
# ... Similar to previous best
# Run 5 stress 0.1275434
# Run 6 stress 0.09513958
# Run 7 stress 0.03282001
# ... Procrustes: rmse 0.0002088609  max resid 0.0005173139
# ... Similar to previous best
# Run 8 stress 0.09763736
# Run 9 stress 0.09513968
# Run 10 stress 0.03282004
# ... Procrustes: rmse 0.0001435475  max resid 0.0003603372
# ... Similar to previous best
# Run 11 stress 0.0328208
# ... Procrustes: rmse 0.0003489681  max resid 0.0008507473
# ... Similar to previous best
# Run 12 stress 0.09513955
# Run 13 stress 0.03282046
# ... Procrustes: rmse 0.000409812  max resid 0.001017841
# ... Similar to previous best
# Run 14 stress 0.03282075
# ... Procrustes: rmse 0.0004786168  max resid 0.001190964
# ... Similar to previous best
# Run 15 stress 0.09513954
# Run 16 stress 0.03282067
# ... Procrustes: rmse 0.0003543935  max resid 0.0008289967
# ... Similar to previous best
# Run 17 stress 0.09513974
# Run 18 stress 0.1275888
# Run 19 stress 0.03282046
# ... Procrustes: rmse 0.0002954275  max resid 0.0007016993
# ... Similar to previous best
# Run 20 stress 0.03281998
# ... Procrustes: rmse 0.0001114789  max resid 0.0002787925
# ... Similar to previous best
# *** Solution reached
# Run 0 stress 0.06953552
# Run 1 stress 0.06953552
# ... Procrustes: rmse 3.048537e-06  max resid 8.281441e-06
# ... Similar to previous best
# Run 2 stress 0.07496303
# Run 3 stress 0.1246665
# Run 4 stress 0.1339297
# Run 5 stress 0.0695357
# ... Procrustes: rmse 4.687994e-05  max resid 0.0001229846
# ... Similar to previous best
# Run 6 stress 0.06953553
# ... Procrustes: rmse 2.124789e-05  max resid 5.9648e-05
# ... Similar to previous best
# Run 7 stress 0.06953552
# ... Procrustes: rmse 1.282858e-06  max resid 2.939273e-06
# ... Similar to previous best
# Run 8 stress 0.1242649
# Run 9 stress 0.06953552
# ... Procrustes: rmse 3.088639e-06  max resid 9.175237e-06
# ... Similar to previous best
# Run 10 stress 0.07496307
# Run 11 stress 0.1242649
# Run 12 stress 0.1246665
# Run 13 stress 0.1375599
# Run 14 stress 0.06953553
# ... Procrustes: rmse 2.754282e-06  max resid 5.147474e-06
# ... Similar to previous best
# Run 15 stress 0.06953553
# ... Procrustes: rmse 2.425499e-05  max resid 7.128574e-05
# ... Similar to previous best
# Run 16 stress 0.06953552
# ... Procrustes: rmse 2.104618e-06  max resid 4.538137e-06
# ... Similar to previous best
# Run 17 stress 0.07496303
# Run 18 stress 0.06953552
# ... Procrustes: rmse 2.370116e-06  max resid 6.560984e-06
# ... Similar to previous best
# Run 19 stress 0.07496303
# Run 20 stress 0.06953552
# ... Procrustes: rmse 1.8174e-06  max resid 4.835749e-06
# ... Similar to previous best
# *** Solution reached
# Run 0 stress 0.07126633
# Run 1 stress 0.07158826
# ... Procrustes: rmse 0.0111556  max resid 0.03192278
# Run 2 stress 0.07158827
# ... Procrustes: rmse 0.01109211  max resid 0.03173324
# Run 3 stress 0.07126637
# ... Procrustes: rmse 6.43262e-05  max resid 0.0001526796
# ... Similar to previous best
# Run 4 stress 0.07126635
# ... Procrustes: rmse 9.001029e-05  max resid 0.0002423056
# ... Similar to previous best
# Run 5 stress 0.07126633
# ... New best solution
# ... Procrustes: rmse 3.319493e-05  max resid 8.921569e-05
# ... Similar to previous best
# Run 6 stress 0.07126639
# ... Procrustes: rmse 3.706221e-05  max resid 8.281803e-05
# ... Similar to previous best
# Run 7 stress 0.07126633
# ... New best solution
# ... Procrustes: rmse 6.161156e-06  max resid 1.889734e-05
# ... Similar to previous best
# Run 8 stress 0.07126642
# ... Procrustes: rmse 0.0001112033  max resid 0.0003129783
# ... Similar to previous best
# Run 9 stress 0.07126634
# ... Procrustes: rmse 3.174144e-05  max resid 9.340384e-05
# ... Similar to previous best
# Run 10 stress 0.07158869
# ... Procrustes: rmse 0.01138121  max resid 0.03240166
# Run 11 stress 0.07126633
# ... New best solution
# ... Procrustes: rmse 5.686794e-06  max resid 1.403214e-05
# ... Similar to previous best
# Run 12 stress 0.1190896
# Run 13 stress 0.07126633
# ... New best solution
# ... Procrustes: rmse 2.380737e-06  max resid 4.27326e-06
# ... Similar to previous best
# Run 14 stress 0.07158839
# ... Procrustes: rmse 0.01126645  max resid 0.03216778
# Run 15 stress 0.07126633
# ... Procrustes: rmse 1.305697e-05  max resid 3.246447e-05
# ... Similar to previous best
# Run 16 stress 0.07158844
# ... Procrustes: rmse 0.01126252  max resid 0.03214661
# Run 17 stress 0.07158826
# ... Procrustes: rmse 0.01115511  max resid 0.03191708
# Run 18 stress 0.07158837
# ... Procrustes: rmse 0.01123122  max resid 0.03209515
# Run 19 stress 0.07126634
# ... Procrustes: rmse 3.825793e-05  max resid 9.039104e-05
# ... Similar to previous best
# Run 20 stress 0.07158857
# ... Procrustes: rmse 0.01134595  max resid 0.03233323
# *** Solution reached
# Run 0 stress 0.1231463
# Run 1 stress 0.1231462
# ... New best solution
# ... Procrustes: rmse 3.278358e-05  max resid 6.937233e-05
# ... Similar to previous best
# Run 2 stress 0.1196991
# ... New best solution
# ... Procrustes: rmse 0.1396909  max resid 0.3624306
# Run 3 stress 0.1196988
# ... New best solution
# ... Procrustes: rmse 0.0002212407  max resid 0.0004100076
# ... Similar to previous best
# Run 4 stress 0.1231462
# Run 5 stress 0.1196999
# ... Procrustes: rmse 0.0005173208  max resid 0.001689041
# ... Similar to previous best
# Run 6 stress 0.119699
# ... Procrustes: rmse 0.0003428534  max resid 0.0006734167
# ... Similar to previous best
# Run 7 stress 0.1231462
# Run 8 stress 0.1197003
# ... Procrustes: rmse 0.0005735889  max resid 0.001332537
# ... Similar to previous best
# Run 9 stress 0.1196987
# ... New best solution
# ... Procrustes: rmse 0.0002427094  max resid 0.0007792993
# ... Similar to previous best
# Run 10 stress 0.1196992
# ... Procrustes: rmse 0.0005100135  max resid 0.001399592
# ... Similar to previous best
# Run 11 stress 0.1196992
# ... Procrustes: rmse 0.0005400252  max resid 0.001793416
# ... Similar to previous best
# Run 12 stress 0.1231462
# Run 13 stress 0.1231462
# Run 14 stress 0.1196994
# ... Procrustes: rmse 0.000390862  max resid 0.0007354924
# ... Similar to previous best
# Run 15 stress 0.1487093
# Run 16 stress 0.1390038
# Run 17 stress 0.1519157
# Run 18 stress 0.1196988
# ... Procrustes: rmse 0.0001477058  max resid 0.0004740101
# ... Similar to previous best
# Run 19 stress 0.1231463
# Run 20 stress 0.1196991
# ... Procrustes: rmse 0.0003418251  max resid 0.001149157
# ... Similar to previous best
# *** Solution reached
# Run 0 stress 0.1076056
# Run 1 stress 0.107606
# ... Procrustes: rmse 0.0003621362  max resid 0.0006214523
# ... Similar to previous best
# Run 2 stress 0.1298616
# Run 3 stress 0.1076066
# ... Procrustes: rmse 0.0008412326  max resid 0.001749485
# ... Similar to previous best
# Run 4 stress 0.1097702
# Run 5 stress 0.1097715
# Run 6 stress 0.1256987
# Run 7 stress 0.3657434
# Run 8 stress 0.1309064
# Run 9 stress 0.1087026
# Run 10 stress 0.1076087
# ... Procrustes: rmse 0.001410603  max resid 0.003081802
# ... Similar to previous best
# Run 11 stress 0.1097716
# Run 12 stress 0.3592953
# Run 13 stress 0.1298604
# Run 14 stress 0.1292907
# Run 15 stress 0.1256982
# Run 16 stress 0.1300522
# Run 17 stress 0.1076075
# ... Procrustes: rmse 0.001134181  max resid 0.002409546
# ... Similar to previous best
# Run 18 stress 0.1292908
# Run 19 stress 0.1087063
# Run 20 stress 0.112376
# *** Solution reached
# Run 0 stress 0.1031991
# Run 1 stress 0.103199
# ... New best solution
# ... Procrustes: rmse 6.555632e-05  max resid 0.0001574016
# ... Similar to previous best
# Run 2 stress 0.1031989
# ... New best solution
# ... Procrustes: rmse 8.27952e-05  max resid 0.0002216142
# ... Similar to previous best
# Run 3 stress 0.103199
# ... Procrustes: rmse 3.814971e-05  max resid 8.057715e-05
# ... Similar to previous best
# Run 4 stress 0.1031992
# ... Procrustes: rmse 0.0001936667  max resid 0.0005047962
# ... Similar to previous best
# Run 5 stress 0.103199
# ... Procrustes: rmse 7.85806e-05  max resid 0.000194815
# ... Similar to previous best
# Run 6 stress 0.209573
# Run 7 stress 0.1031989
# ... Procrustes: rmse 3.720172e-05  max resid 9.840716e-05
# ... Similar to previous best
# Run 8 stress 0.1031989
# ... Procrustes: rmse 6.00517e-05  max resid 0.000161073
# ... Similar to previous best
# Run 9 stress 0.1031989
# ... Procrustes: rmse 2.815716e-05  max resid 6.887721e-05
# ... Similar to previous best
# Run 10 stress 0.1881436
# Run 11 stress 0.1031989
# ... Procrustes: rmse 5.626844e-06  max resid 1.341638e-05
# ... Similar to previous best
# Run 12 stress 0.103199
# ... Procrustes: rmse 7.705132e-05  max resid 0.0002068823
# ... Similar to previous best
# Run 13 stress 0.2002447
# Run 14 stress 0.103199
# ... Procrustes: rmse 3.577899e-05  max resid 5.936754e-05
# ... Similar to previous best
# Run 15 stress 0.103199
# ... Procrustes: rmse 0.0001469106  max resid 0.0003912836
# ... Similar to previous best
# Run 16 stress 0.1494287
# Run 17 stress 0.1031989
# ... Procrustes: rmse 3.162161e-05  max resid 8.124004e-05
# ... Similar to previous best
# Run 18 stress 0.1031989
# ... New best solution
# ... Procrustes: rmse 1.293267e-05  max resid 3.482569e-05
# ... Similar to previous best
# Run 19 stress 0.1031989
# ... Procrustes: rmse 5.264009e-05  max resid 0.0001425283
# ... Similar to previous best
# Run 20 stress 0.103199
# ... Procrustes: rmse 9.866674e-05  max resid 0.0002623902
# ... Similar to previous best
# *** Solution reached

# %% [markdown]
# # Code for statistical comparisons in manuscript:
# Below you'll find the code used to make statistical comparisons of:
# * sequencing results with linear models
# * mapping results with linear models
# * diversity indices with the Wilcoxon test
# * Ordination clustering with ANOSIM
#
# For the differential abundance tests, results can be found in the "stats" directory. The code for replicating this analysis is part of the "print_microbiome_ZIG_results.R" script with further details in "meg_utility_functions.R".

# %% [markdown]
# ## Linear models comparing sequencing and mapping results

# %%
#
##
### GLM for read counts by Treatment, Dilution, Packaging
##
#

summary(glm(metadata$Raw_paired_reads ~ as.factor(metadata$Treatment)))
summary(glm(metadata$Raw_paired_reads ~ as.factor(metadata$Dilution)))
summary(glm(metadata$Raw_paired_reads ~ as.factor(metadata$Packaging)))

summary(glm(metadata$QC_filtered_reads ~ as.factor(metadata$Treatment)))
summary(glm(metadata$QC_filtered_reads ~ as.factor(metadata$Dilution)))
summary(glm(metadata$QC_filtered_reads ~ as.factor(metadata$Packaging)))

summary(glm(metadata$nonhost_filtered_reads ~ as.factor(metadata$Treatment)))
summary(glm(metadata$nonhost_filtered_reads ~ as.factor(metadata$Dilution)))
summary(glm(metadata$nonhost_filtered_reads ~ as.factor(metadata$Packaging)))

summary(glm(metadata$deduped_SNP_confirmed_counts ~ as.factor(metadata$Treatment)))
summary(glm(metadata$deduped_SNP_confirmed_counts ~ as.factor(metadata$Dilution)))
summary(glm(metadata$deduped_SNP_confirmed_counts ~ as.factor(metadata$Packaging)))

## GLM microbome
summary(glm(microbiome_metadata$Raw_paired_reads ~ as.factor(microbiome_metadata$Treatment)))
summary(glm(microbiome_metadata$Raw_paired_reads ~ as.factor(microbiome_metadata$Packaging)))

summary(glm(microbiome_metadata$QC_filtered_reads ~ as.factor(microbiome_metadata$Treatment)))
summary(glm(microbiome_metadata$QC_filtered_reads ~ as.factor(microbiome_metadata$Packaging)))

summary(glm(microbiome_metadata$nonhost_filtered_reads ~ as.factor(microbiome_metadata$Treatment)))
summary(glm(microbiome_metadata$nonhost_filtered_reads ~ as.factor(microbiome_metadata$Dilution)))
# Out:
# Call:
# glm(formula = metadata$Raw_paired_reads ~ as.factor(metadata$Treatment))
#
# Deviance Residuals:
#       Min         1Q     Median         3Q        Max
# -28371413   -3892180     975073    5738760   22305922
#
# Coefficients:
#                                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)                       48267065    2685076  17.976  < 2e-16 ***
# as.factor(metadata$Treatment)RWA -11350777    3797271  -2.989  0.00554 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 1.153542e+14)
#
#     Null deviance: 4.4913e+15  on 31  degrees of freedom
# Residual deviance: 3.4606e+15  on 30  degrees of freedom
# AIC: 1130.9
#
# Number of Fisher Scoring iterations: 2
# Call:
# glm(formula = metadata$Raw_paired_reads ~ as.factor(metadata$Dilution))
#
# Deviance Residuals:
#       Min         1Q     Median         3Q        Max
# -33815425   -4914615    1125198    7639976   24698063
#
# Coefficients:
#                                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)                      42360299    3058333  13.851 1.43e-14 ***
# as.factor(metadata$Dilution)None   462754    4325136   0.107    0.916
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 1.496544e+14)
#
#     Null deviance: 4.4913e+15  on 31  degrees of freedom
# Residual deviance: 4.4896e+15  on 30  degrees of freedom
# AIC: 1139.2
#
# Number of Fisher Scoring iterations: 2
# Call:
# glm(formula = metadata$Raw_paired_reads ~ as.factor(metadata$Packaging))
#
# Deviance Residuals:
#       Min         1Q     Median         3Q        Max
# -28371413   -3785593     663162    4968917   22305922
#
# Coefficients:
#                                            Estimate Std. Error t value Pr(>|t|)
# (Intercept)                                51258930    3840625  13.347 1.16e-13
# as.factor(metadata$Packaging)StoreGrind    -3749240    8587899  -0.437  0.66577
# as.factor(metadata$Packaging)TrayOverwrap  -6728561    5866652  -1.147  0.26112
# as.factor(metadata$Packaging)Vacuum       -14342643    4703786  -3.049  0.00497
#
# (Intercept)                               ***
# as.factor(metadata$Packaging)StoreGrind
# as.factor(metadata$Packaging)TrayOverwrap
# as.factor(metadata$Packaging)Vacuum       **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 1.180032e+14)
#
#     Null deviance: 4.4913e+15  on 31  degrees of freedom
# Residual deviance: 3.3041e+15  on 28  degrees of freedom
# AIC: 1133.4
#
# Number of Fisher Scoring iterations: 2
# Call:
# glm(formula = metadata$QC_filtered_reads ~ as.factor(metadata$Treatment))
#
# Deviance Residuals:
#       Min         1Q     Median         3Q        Max
# -27288015   -3559916     980090    5600911   21579012
#
# Coefficients:
#                                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)                       46491186    2587791  17.966  < 2e-16 ***
# as.factor(metadata$Treatment)RWA -10954020    3659690  -2.993  0.00548 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 1.071466e+14)
#
#     Null deviance: 4.1743e+15  on 31  degrees of freedom
# Residual deviance: 3.2144e+15  on 30  degrees of freedom
# AIC: 1128.5
#
# Number of Fisher Scoring iterations: 2
# Call:
# glm(formula = metadata$QC_filtered_reads ~ as.factor(metadata$Dilution))
#
# Deviance Residuals:
#       Min         1Q     Median         3Q        Max
# -32579208   -4713845    1138110    7633858   23751412
#
# Coefficients:
#                                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)                      40828358    2948594  13.847 1.44e-14 ***
# as.factor(metadata$Dilution)None   371635    4169941   0.089     0.93
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 1.391073e+14)
#
#     Null deviance: 4.1743e+15  on 31  degrees of freedom
# Residual deviance: 4.1732e+15  on 30  degrees of freedom
# AIC: 1136.9
#
# Number of Fisher Scoring iterations: 2
# Call:
# glm(formula = metadata$QC_filtered_reads ~ as.factor(metadata$Packaging))
#
# Deviance Residuals:
#       Min         1Q     Median         3Q        Max
# -27288015   -3739430     672672    4899721   21579012
#
# Coefficients:
#                                            Estimate Std. Error t value Pr(>|t|)
# (Intercept)                                49387650    3699139  13.351 1.15e-13
# as.factor(metadata$Packaging)StoreGrind    -3418606    8271527  -0.413  0.68254
# as.factor(metadata$Packaging)TrayOverwrap  -6584371    5650529  -1.165  0.25374
# as.factor(metadata$Packaging)Vacuum       -13850485    4530502  -3.057  0.00487
#
# (Intercept)                               ***
# as.factor(metadata$Packaging)StoreGrind
# as.factor(metadata$Packaging)TrayOverwrap
# as.factor(metadata$Packaging)Vacuum       **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 1.094691e+14)
#
#     Null deviance: 4.1743e+15  on 31  degrees of freedom
# Residual deviance: 3.0651e+15  on 28  degrees of freedom
# AIC: 1131
#
# Number of Fisher Scoring iterations: 2
# Call:
# glm(formula = metadata$nonhost_filtered_reads ~ as.factor(metadata$Treatment))
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -400623  -259565   -28923    84455   968543
#
# Coefficients:
#                                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)                        442106      81683   5.412 7.27e-06 ***
# as.factor(metadata$Treatment)RWA  -374414     115518  -3.241  0.00291 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 106754534437)
#
#     Null deviance: 4.3241e+12  on 31  degrees of freedom
# Residual deviance: 3.2026e+12  on 30  degrees of freedom
# AIC: 907.35
#
# Number of Fisher Scoring iterations: 2
# Call:
# glm(formula = metadata$nonhost_filtered_reads ~ as.factor(metadata$Dilution))
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -251875  -211044  -164093   -79693  1158264
#
# Coefficients:
#                                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)                        257413      94911   2.712    0.011 *
# as.factor(metadata$Dilution)None    -5029     134225  -0.037    0.970
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 144130645182)
#
#     Null deviance: 4.3241e+12  on 31  degrees of freedom
# Residual deviance: 4.3239e+12  on 30  degrees of freedom
# AIC: 916.95
#
# Number of Fisher Scoring iterations: 2
# Call:
# glm(formula = metadata$nonhost_filtered_reads ~ as.factor(metadata$Packaging))
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -447276  -122568   -16073    84455   921890
#
# Coefficients:
#                                           Estimate Std. Error t value Pr(>|t|)
# (Intercept)                                 502982     113110   4.447 0.000126
# as.factor(metadata$Packaging)StoreGrind    -444338     252922  -1.757 0.089882
# as.factor(metadata$Packaging)TrayOverwrap   -14222     172779  -0.082 0.934981
# as.factor(metadata$Packaging)Vacuum        -435289     138531  -3.142 0.003940
#
# (Intercept)                               ***
# as.factor(metadata$Packaging)StoreGrind   .
# as.factor(metadata$Packaging)TrayOverwrap
# as.factor(metadata$Packaging)Vacuum       **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 102351578420)
#
#     Null deviance: 4.3241e+12  on 31  degrees of freedom
# Residual deviance: 2.8658e+12  on 28  degrees of freedom
# AIC: 907.79
#
# Number of Fisher Scoring iterations: 2
# Call:
# glm(formula = metadata$deduped_SNP_confirmed_counts ~ as.factor(metadata$Treatment))
#
# Deviance Residuals:
#    Min      1Q  Median      3Q     Max
# -12644   -7334   -3138    3566   39089
#
# Coefficients:
#                                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)                         12779       2873   4.447  0.00011 ***
# as.factor(metadata$Treatment)RWA    -8813       4064  -2.169  0.03816 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 132103390)
#
#     Null deviance: 4584435824  on 31  degrees of freedom
# Residual deviance: 3963101698  on 30  degrees of freedom
# AIC: 693.12
#
# Number of Fisher Scoring iterations: 2
# Call:
# glm(formula = metadata$deduped_SNP_confirmed_counts ~ as.factor(metadata$Dilution))
#
# Deviance Residuals:
#    Min      1Q  Median      3Q     Max
#  -8787   -7474   -5927    1754   43001
#
# Coefficients:
#                                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)                        7878.2     3087.8   2.551   0.0161 *
# as.factor(metadata$Dilution)None    988.8     4366.8   0.226   0.8224
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 152553827)
#
#     Null deviance: 4584435824  on 31  degrees of freedom
# Residual deviance: 4576614811  on 30  degrees of freedom
# AIC: 697.72
#
# Number of Fisher Scoring iterations: 2
# Call:
# glm(formula = metadata$deduped_SNP_confirmed_counts ~ as.factor(metadata$Packaging))
#
# Deviance Residuals:
#    Min      1Q  Median      3Q     Max
# -18554   -3871   -2715    3678   31695
#
# Coefficients:
#                                           Estimate Std. Error t value Pr(>|t|)
# (Intercept)                                  20173       3670   5.497 7.14e-06
# as.factor(metadata$Packaging)StoreGrind     -19972       8206  -2.434   0.0216
# as.factor(metadata$Packaging)TrayOverwrap   -13059       5606  -2.330   0.0273
# as.factor(metadata$Packaging)Vacuum         -16207       4495  -3.606   0.0012
#
# (Intercept)                               ***
# as.factor(metadata$Packaging)StoreGrind   *
# as.factor(metadata$Packaging)TrayOverwrap *
# as.factor(metadata$Packaging)Vacuum       **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 107740597)
#
#     Null deviance: 4584435824  on 31  degrees of freedom
# Residual deviance: 3016736719  on 28  degrees of freedom
# AIC: 688.39
#
# Number of Fisher Scoring iterations: 2
# Call:
# glm(formula = microbiome_metadata$Raw_paired_reads ~ as.factor(microbiome_metadata$Treatment))
#
# Deviance Residuals:
#    Min      1Q  Median      3Q     Max
# -86865   -8159   10299   17934   28431
#
# Coefficients:
#                                             Estimate Std. Error t value
# (Intercept)                                   187804      10769  17.439
# as.factor(microbiome_metadata$Treatment)RWA    13208      15230   0.867
#                                             Pr(>|t|)
# (Intercept)                                 6.83e-11 ***
# as.factor(microbiome_metadata$Treatment)RWA      0.4
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 927819427)
#
#     Null deviance: 1.3687e+10  on 15  degrees of freedom
# Residual deviance: 1.2989e+10  on 14  degrees of freedom
# AIC: 379.64
#
# Number of Fisher Scoring iterations: 2
# Call:
# glm(formula = microbiome_metadata$Raw_paired_reads ~ as.factor(microbiome_metadata$Packaging))
#
# Deviance Residuals:
#    Min      1Q  Median      3Q     Max
# -63255   -3280    6134   11863   49150
#
# Coefficients:
#                                                      Estimate Std. Error
# (Intercept)                                            198404      14477
# as.factor(microbiome_metadata$Packaging)StoreGrind      17831      32371
# as.factor(microbiome_metadata$Packaging)TrayOverwrap   -34210      22113
# as.factor(microbiome_metadata$Packaging)Vacuum           2608      17730
#                                                      t value Pr(>|t|)
# (Intercept)                                           13.705 1.09e-08 ***
# as.factor(microbiome_metadata$Packaging)StoreGrind     0.551    0.592
# as.factor(microbiome_metadata$Packaging)TrayOverwrap  -1.547    0.148
# as.factor(microbiome_metadata$Packaging)Vacuum         0.147    0.885
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 838288428)
#
#     Null deviance: 1.3687e+10  on 15  degrees of freedom
# Residual deviance: 1.0059e+10  on 12  degrees of freedom
# AIC: 379.55
#
# Number of Fisher Scoring iterations: 2
# Call:
# glm(formula = microbiome_metadata$QC_filtered_reads ~ as.factor(microbiome_metadata$Treatment))
#
# Deviance Residuals:
#    Min      1Q  Median      3Q     Max
# -81138   -8558    9738   14918   28213
#
# Coefficients:
#                                             Estimate Std. Error t value
# (Intercept)                                   175707      10161  17.293
# as.factor(microbiome_metadata$Treatment)RWA     8955      14369   0.623
#                                             Pr(>|t|)
# (Intercept)                                 7.65e-11 ***
# as.factor(microbiome_metadata$Treatment)RWA    0.543
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 825903602)
#
#     Null deviance: 1.1883e+10  on 15  degrees of freedom
# Residual deviance: 1.1563e+10  on 14  degrees of freedom
# AIC: 377.78
#
# Number of Fisher Scoring iterations: 2
# Call:
# glm(formula = microbiome_metadata$QC_filtered_reads ~ as.factor(microbiome_metadata$Packaging))
#
# Deviance Residuals:
#    Min      1Q  Median      3Q     Max
# -58946   -2966    5467   10273   49662
#
# Coefficients:
#                                                      Estimate Std. Error
# (Intercept)                                          185297.2    13633.1
# as.factor(microbiome_metadata$Packaging)StoreGrind    18622.8    30484.6
# as.factor(microbiome_metadata$Packaging)TrayOverwrap -31781.9    20824.9
# as.factor(microbiome_metadata$Packaging)Vacuum         -635.1    16697.1
#                                                      t value Pr(>|t|)
# (Intercept)                                           13.592 1.19e-08 ***
# as.factor(microbiome_metadata$Packaging)StoreGrind     0.611    0.553
# as.factor(microbiome_metadata$Packaging)TrayOverwrap  -1.526    0.153
# as.factor(microbiome_metadata$Packaging)Vacuum        -0.038    0.970
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 743447939)
#
#     Null deviance: 1.1883e+10  on 15  degrees of freedom
# Residual deviance: 8.9214e+09  on 12  degrees of freedom
# AIC: 377.63
#
# Number of Fisher Scoring iterations: 2
# Error in model.frame.default(formula = microbiome_metadata$nonhost_filtered_reads ~ : invalid type (NULL) for variable 'microbiome_metadata$nonhost_filtered_reads'
# Traceback:
#
# 1. summary(glm(microbiome_metadata$nonhost_filtered_reads ~ as.factor(microbiome_metadata$Treatment)))
# 2. glm(microbiome_metadata$nonhost_filtered_reads ~ as.factor(microbiome_metadata$Treatment))
# 3. eval(mf, parent.frame())
# 4. eval(mf, parent.frame())
# 5. stats::model.frame(formula = microbiome_metadata$nonhost_filtered_reads ~
#  .     as.factor(microbiome_metadata$Treatment), drop.unused.levels = TRUE)
# 6. model.frame.default(formula = microbiome_metadata$nonhost_filtered_reads ~
#  .     as.factor(microbiome_metadata$Treatment), drop.unused.levels = TRUE)

# %% [markdown]
# ## Resistome statistical comparisons

# %%
## Wilcoxon test of diversity indices by Treatment and Dilution
#
# Test by treatment, Class and Mech
wilcox.test(metadata$AMR_class_Richness ~ metadata$Treatment)
wilcox.test(metadata$AMR_class_Shannon ~ metadata$Treatment)
wilcox.test(metadata$AMR_class_Richness ~ metadata$Treatment)
wilcox.test(metadata$AMR_class_Shannon ~ metadata$Treatment)
# Test by Dilution, Class and Mech
wilcox.test(metadata$AMR_class_Richness ~ metadata$Dilution)
wilcox.test(metadata$AMR_class_Shannon ~ metadata$Dilution)
wilcox.test(metadata$AMR_class_Richness ~ metadata$Dilution)
wilcox.test(metadata$AMR_class_Shannon ~ metadata$Dilution)

## ANOSIM clustering at the Class and Mechanism level
#
# Dilution
anosim(metaMDS_AMR_class$points,pData(AMR_analytic_data[[1]])$Dilution, distance='euclidean')
anosim(metaMDS_AMR_mech$points,pData(AMR_analytic_data[[2]])$Dilution, distance='euclidean')
# Treatment
anosim(metaMDS_AMR_class$points,pData(AMR_analytic_data[[1]])$Treatment, distance='euclidean')
anosim(metaMDS_AMR_mech$points,pData(AMR_analytic_data[[2]])$Treatment, distance='euclidean')
# Packaging
anosim(metaMDS_AMR_class$points,pData(AMR_analytic_data[[1]])$Packaging, distance='euclidean')
anosim(metaMDS_AMR_mech$points,pData(AMR_analytic_data[[2]])$Packaging, distance='euclidean')
# Blinded Store
anosim(metaMDS_AMR_class$points,pData(AMR_analytic_data[[1]])$Blinded_Store, distance='euclidean')
anosim(metaMDS_AMR_mech$points,pData(AMR_analytic_data[[2]])$Blinded_Store, distance='euclidean')

# %% [markdown]
# ## Microbiome statistical comparisons

# %%
## Wilcoxon test of diversity indices by Treatment at each taxonomic level
#
wilcox.test(microbiome_metadata$microbiome_phylum_Richness ~ microbiome_metadata$Treatment)
wilcox.test(microbiome_metadata$microbiome_phylum_Shannon ~ microbiome_metadata$Treatment)

wilcox.test(microbiome_metadata$microbiome_class_Richness ~ microbiome_metadata$Treatment)
wilcox.test(microbiome_metadata$microbiome_class_Shannon ~ microbiome_metadata$Treatment)

wilcox.test(microbiome_metadata$microbiome_order_Richness ~ microbiome_metadata$Treatment)
wilcox.test(microbiome_metadata$microbiome_order_Shannon ~ microbiome_metadata$Treatment)

wilcox.test(microbiome_metadata$microbiome_family_Richness ~ microbiome_metadata$Treatment)
wilcox.test(microbiome_metadata$microbiome_family_Shannon ~ microbiome_metadata$Treatment)

wilcox.test(microbiome_metadata$microbiome_genus_Richness ~ microbiome_metadata$Treatment)
wilcox.test(microbiome_metadata$microbiome_genus_Shannon ~ microbiome_metadata$Treatment)

wilcox.test(microbiome_metadata$microbiome_species_Richness ~ microbiome_metadata$Treatment)
wilcox.test(microbiome_metadata$microbiome_species_Shannon ~ microbiome_metadata$Treatment)

## ANOSIM clustering at each microbiome taxonomic level
#
# Treatment
anosim(metaMDS_microbiome_phylum$points,pData(microbiome_analytic_data[[2]])$Treatment, distance='euclidean')
anosim(metaMDS_microbiome_class$points,pData(microbiome_analytic_data[[3]])$Treatment, distance='euclidean')
anosim(metaMDS_microbiome_order$points,pData(microbiome_analytic_data[[4]])$Treatment, distance='euclidean')
anosim(metaMDS_microbiome_family$points,pData(microbiome_analytic_data[[5]])$Treatment, distance='euclidean')
anosim(metaMDS_microbiome_genus$points,pData(microbiome_analytic_data[[6]])$Treatment, distance='euclidean')
anosim(metaMDS_microbiome_species$points,pData(microbiome_analytic_data[[7]])$Treatment, distance='euclidean')
# Packaging
anosim(metaMDS_microbiome_phylum$points,pData(microbiome_analytic_data[[2]])$Packaging, distance='euclidean')
anosim(metaMDS_microbiome_class$points,pData(microbiome_analytic_data[[3]])$Packaging, distance='euclidean')
anosim(metaMDS_microbiome_order$points,pData(microbiome_analytic_data[[4]])$Packaging, distance='euclidean')
anosim(metaMDS_microbiome_family$points,pData(microbiome_analytic_data[[5]])$Packaging, distance='euclidean')
anosim(metaMDS_microbiome_genus$points,pData(microbiome_analytic_data[[6]])$Packaging, distance='euclidean')
anosim(metaMDS_microbiome_species$points,pData(microbiome_analytic_data[[7]])$Packaging, distance='euclidean')
# Blinded_Store
anosim(metaMDS_microbiome_phylum$points,pData(microbiome_analytic_data[[2]])$Blinded_Store, distance='euclidean')
anosim(metaMDS_microbiome_class$points,pData(microbiome_analytic_data[[3]])$Blinded_Store, distance='euclidean')
anosim(metaMDS_microbiome_order$points,pData(microbiome_analytic_data[[4]])$Blinded_Store, distance='euclidean')
anosim(metaMDS_microbiome_family$points,pData(microbiome_analytic_data[[5]])$Blinded_Store, distance='euclidean')
anosim(metaMDS_microbiome_genus$points,pData(microbiome_analytic_data[[6]])$Blinded_Store, distance='euclidean')
anosim(metaMDS_microbiome_species$points,pData(microbiome_analytic_data[[7]])$Blinded_Store, distance='euclidean')

# %% [markdown]
# # Making other figures
#
# ### Running the blocks above loaded some useful R objects to explore
# * Resistome
#   * amr_melted_analytic
#   * amr_raw_melted_analytic
#   * AMR_analytic_data
#    * List of MRexperiment objects at each level; Class, Mechanism, Group, Gene
# * Microbiome
#   * microbiome_melted_analytic
#   * microbiome_raw_melted_analytic
#   * microbiome_analytic_data
#    * List of MRexperiment objects at each level; Domain, Phylum, Class, Order, Family, Genus, Species

# %% [markdown]
# ## Counts and percentage for each microbiome taxa level
# For example, below we can calculate how many of the total mapped reads were classified at each taxonomic level

# %%
micro_counts = microbiome_melted_analytic[,.(sum = sum(Normalized_Count) ), by = .(Level_ID)][,percentage := (sum/2357277.6) * 100,]
micro_counts
micro_counts
# Out:
#   Level_ID sum       percentage
# 1 Domain   2357277.6 100.000000
# 2 Phylum   2065855.6  87.637351
# 3 Class    2065486.5  87.621693
# 4 Order    2063275.9  87.527913
# 5 Family   1992674.7  84.532882
# 6 Genus    1846752.0  78.342577
# 7 Species   157363.1   6.675628

# %% [markdown]
# ## Counts and percentage for each microbiome taxa level by Treatment group (CONV vs RWA)

# %%
micro_counts <- microbiome_melted_analytic[,.(sum_taxa = sum(Normalized_Count) ), by = .(Level_ID, Treatment)]
micro_counts[Treatment =="RWA",percentage := (sum_taxa/1166527.90) * 100, by = .(Level_ID)]
micro_counts[Treatment =="CONV",percentage := (sum_taxa/1190749.69) * 100, by = .(Level_ID)]
micro_counts
# Out:
#    Level_ID Treatment sum_taxa   percentage
# 1  Domain   RWA       1166527.90 100.000000
# 2  Phylum   RWA        995561.75  85.344016
# 3  Class    RWA        995357.64  85.326518
# 4  Order    RWA        994082.14  85.217177
# 5  Family   RWA        946728.58  81.157817
# 6  Genus    RWA        870357.03  74.610906
# 7  Species  RWA         84238.43   7.221296
# 8  Domain   CONV      1190749.69 100.000000
# 9  Phylum   CONV      1070293.88  89.884036
# 10 Class    CONV      1070128.91  89.870182
# 11 Order    CONV      1069193.74  89.791646
# 12 Family   CONV      1045946.11  87.839293
# 13 Genus    CONV       976395.00  81.998342
# 14 Species  CONV        73124.64   6.141059

# %% [markdown]
# # Create plots below

# %%
## Figure 2 showing resistome composition
AMR_class_sum <- amr_melted_analytic[Level_ID=="Class", .(sum_class= sum(Normalized_Count)),by=.(ID, Name, Packaging, Treatment)][order(-Packaging )]
AMR_class_sum[,total:= sum(sum_class), by=.(ID)]
AMR_class_sum[,percentage:= sum_class/total ,by=.(ID, Name) ]
AMR_class_sum$Class <- AMR_class_sum$Name
fig1 <- ggplot(AMR_class_sum, aes(x = ID, y = percentage, fill = Class)) + 
  geom_bar(stat = "identity",colour = "black")+
  facet_wrap( ~ Treatment, scales='free',ncol = 2) +
  #scale_fill_brewer(palette="Dark2") +
  theme(
    panel.grid.major=element_blank(),
    panel.grid.minor=element_blank(),
    strip.text.x=element_text(size=16),
    strip.text.y=element_text(size=16, angle=0),
    axis.text.x=element_blank(), #element_text(size=16, angle=20, hjust=1)
    axis.text.y=element_text(size=16),
    axis.title=element_text(size=16),
    legend.position="right",
    panel.spacing=unit(0.1, "lines"),
    plot.title=element_text(size=16, hjust=0.5),
    legend.text=element_text(size=10),
    legend.title=element_text(size=16),
    panel.background = element_rect(fill = "white")
  ) +
  ggtitle("\t\tResistome composition by label") +
  xlab('Sample') +
  ylab('Relative abundance') +
  scale_fill_tableau("Tableau 20") 
fig1
# Out:
# plot without title
